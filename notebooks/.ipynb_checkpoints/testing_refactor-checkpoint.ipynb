# %%
library(crigen)
# Out:
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: listenv
#
# Loading required package: pbapply
#
# Loading required package: parallel
#
# Loading required package: dynutils
#
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::as_data_frame() masks tibble::as_data_frame(), igraph::as_data_frame()
# ✖ purrr::compose()       masks igraph::compose()
# ✖ tidyr::crossing()      masks igraph::crossing()
# ✖ dplyr::filter()        masks stats::filter()
# ...

# %%
# deposit_id <- 5175909
# temp <- "~/.cache/dyngen"

# load(file="../data/fantom5.RData")
# load(file="../data/realcounts.RData")

# files <- GET(glue::glue("https://zenodo.org/api/records/{deposit_id}")) %>%
#               httr::content() %>% .$files %>% map(unlist) %>% list_as_tibble() %>%
#               mutate(dataset_id = str_replace(filename, "\\.Rds$", ""))

# fantom5 <- files %>% filter(dataset_id %in% names(fantom5))
# realcounts <- files %>% filter(!dataset_id %in% names(fantom5))

# save(fantom5, file="../data/fantom5.RData")
# save(realcounts, file="../data/realcounts.RData")

# %%
pbo <- pboptions(type = 'timer')

# %%
model <- create_network(num_tfs=10, num_egenes=100, num_hks=100) %>%
            initialize_kinetics() %>% 
            create_grnas(on_target=0, off_target=0, ngrna_per_target=1) %>%
            run_simulation(nsims_per_grna=1) %>%
            downsampling_molecule()
# Out:
# Creating GRN...
#
# GRN Created...
#
# Creating HK Network...
#
# HK Network Created...
#
# Initializing Networks Kinetics...
#   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01s
# Selecting Target Genes...
#
# Creating gRNA Characteristics...
#   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=03m 32s

# %%
model$feature_network %>%
    filter(grepl('TF', from) & grepl('TF', to)) %>%
    igraph::graph_from_data_frame() %>% plot()
# Out:
# Plot with title “”
