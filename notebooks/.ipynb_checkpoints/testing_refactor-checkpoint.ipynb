# %%
library(crigen)
# Out:
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: future
#
#
# Attaching package: ‘future’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     %->%, %<-%
#
#
# Loading required package: listenv
#
# Loading required package: pbapply
#
# Loading required package: parallel
#
# Loading required package: dynutils
#
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::as_data_frame() masks tibble::as_data_frame(), igraph::as_data_frame()
# ✖ purrr::compose()       masks igraph::compose()
# ✖ tidyr::crossing()      masks igraph::crossing()
# ✖ dplyr::filter()        masks stats::filter()
# ✖ dplyr::groups()        masks igraph::groups()
# ✖ dplyr::lag()           masks stats::lag()
# ✖ purrr::map()           masks listenv::map()
# ✖ purrr::simplify()      masks igraph::simplify()
#
# Loading required package: assertthat
#
#
# Attaching package: ‘assertthat’
#
#
# The following object is masked from ‘package:tibble’:
#
#     has_name
#
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# Loading required package: future.apply
#
# Loading required package: GillespieSSA2
#
# Loading required package: future.batchtools

# %%
pbo <- pboptions(type = 'timer')
options(batchtools.progress=TRUE)

# %%
model <- create_network(num_tfs=10, num_egenes=100, num_hks=100) %>%
            initialize_kinetics() %>% 
            create_grnas(on_target=0, off_target=1, ngrna_per_target=1, crispr_type='Knockout')
# Out:
# Creating GRN...
#
# GRN Created...
#
# Creating HK Network...
#
# HK Network Created...
#
# Initializing Networks Kinetics...
#   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01s
# Selecting Target Genes...
#
# Creating gRNA Characteristics...

# %%
model$feature_network %>%
    filter(grepl('TF', from) & grepl('TF', to)) %>%
    igraph::graph_from_data_frame() %>% plot()
# Out:
# Plot with title “”

# %%
model <- model %>%
            run_simulation(cluster='slurm', nsims_per_grna=1) %>%
            create_experiment()

# %%
names(model)
# Out:
#  [1] "feature_network"   "feature_info"      "verbose"
#  [4] "simulation_system" "crispr_params"     "target_genes"
#  [7] "grnas_meta"        "sim_meta"          "simulation"
# [10] "experiment"

# %%
names(model$experiment)
# Out:
# [1] "cell_info"      "mrna"           "unspliced_mrna" "spliced_mrna"

# %%
model$experiment$cell_info
# Out:
#      cell_id  step_ix target_gene grna       sim_name         phase    time
# 1    cell1    128     CTRL        CTRL       CTRL-sim.1       sampling 255
# 2    cell2     70     CTRL        CTRL       CTRL-sim.1       sampling 139
# 3    cell3    193     CTRL        CTRL       CTRL-sim.1       sampling 385
# 4    cell4     42     CTRL        CTRL       CTRL-sim.1       sampling  83
# 5    cell5     61     CTRL        CTRL       CTRL-sim.1       sampling 121
# 6    cell6    185     CTRL        CTRL       CTRL-sim.1       sampling 369
# 7    cell7    194     CTRL        CTRL       CTRL-sim.1       sampling 387
# 8    cell8    126     CTRL        CTRL       CTRL-sim.1       sampling 251
# 9    cell9    148     CTRL        CTRL       CTRL-sim.1       sampling 295
# 10   cell10   102     CTRL        CTRL       CTRL-sim.1       sampling 203
# 11   cell11   161     CTRL        CTRL       CTRL-sim.1       sampling 321
# 12   cell12   156     CTRL        CTRL       CTRL-sim.1       sampling 311
# 13   cell13   169     CTRL        CTRL       CTRL-sim.1       sampling 337
# 14   cell14   144     CTRL        CTRL       CTRL-sim.1       sampling 287
# 15   cell15   100     CTRL        CTRL       CTRL-sim.1       sampling 199
# 16   cell16   110     CTRL        CTRL       CTRL-sim.1       sampling 219
# 17   cell17   119     CTRL        CTRL       CTRL-sim.1       sampling 237
# 18   cell18   152     CTRL        CTRL       CTRL-sim.1       sampling 303
# 19   cell19   106     CTRL        CTRL       CTRL-sim.1       sampling 211
# 20   cell20   128     CTRL        CTRL       CTRL-sim.1       sampling 255
# 21   cell21    48     CTRL        CTRL       CTRL-sim.1       sampling  95
# 22   cell22   125     CTRL        CTRL       CTRL-sim.1       sampling 249
# 23   cell23    98     CTRL        CTRL       CTRL-sim.1       sampling 195
# 24   cell24    54     CTRL        CTRL       CTRL-sim.1       sampling 107
# 25   cell25    95     CTRL        CTRL       CTRL-sim.1       sampling 189
# 26   cell26   182     CTRL        CTRL       CTRL-sim.1       sampling 363
# 27   cell27   112     CTRL        CTRL       CTRL-sim.1       sampling 223
# 28   cell28   119     CTRL        CTRL       CTRL-sim.1       sampling 237
# 29   cell29   159     CTRL        CTRL       CTRL-sim.1       sampling 317
# 30   cell30   164     CTRL        CTRL       CTRL-sim.1       sampling 327
# ⋮    ⋮        ⋮       ⋮           ⋮          ⋮                ⋮        ⋮
# 1071 cell1071 2156    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 291
# 1072 cell1072 2155    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 289
# 1073 cell1073 2033    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  45
# 1074 cell1074 2048    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  75
# 1075 cell1075 2014    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling   7
# 1076 cell1076 2144    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 267
# 1077 cell1077 2181    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 341
# 1078 cell1078 2012    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling   3
# 1079 cell1079 2126    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 231
# 1080 cell1080 2093    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 165
# 1081 cell1081 2199    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 377
# 1082 cell1082 2083    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 145
# 1083 cell1083 2106    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 191
# 1084 cell1084 2154    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 287
# 1085 cell1085 2046    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  71
# 1086 cell1086 2114    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 207
# 1087 cell1087 2132    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 243
# 1088 cell1088 2029    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  37
# 1089 cell1089 2146    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 271
# 1090 cell1090 2093    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 165
# 1091 cell1091 2130    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 239
# 1092 cell1092 2019    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  17
# 1093 cell1093 2016    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  11
# 1094 cell1094 2082    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 143
# 1095 cell1095 2142    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 263
# 1096 cell1096 2141    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 261
# 1097 cell1097 2042    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  63
# 1098 cell1098 2041    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling  61
# 1099 cell1099 2065    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling 109
# 1100 cell1100 2011    TF1         TF1-grna.1 TF1-grna.1-sim.1 sampling   0
