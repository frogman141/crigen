# %%
library(dyngen)
library(igraph)
library(future)
library(listenv)
library(pbapply)
library(dynutils)
library(tidyverse)
library(batchtools)
library(assertthat)
library(future.apply)
library(GillespieSSA2)
library(future.batchtools)
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
#
# Attaching package: ‘future’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     %->%, %<-%
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::as_data_frame() masks tibble::as_data_frame(), igraph::as_data_frame()
# ✖ purrr::compose()       masks igraph::compose()
# ✖ tidyr::crossing()      masks igraph::crossing()
# ✖ dplyr::filter()        masks stats::filter()
# ✖ dplyr::groups()        masks igraph::groups()
# ✖ dplyr::lag()           masks stats::lag()
# ✖ purrr::map()           masks listenv::map()
# ✖ purrr::simplify()      masks igraph::simplify()
#
#
# Attaching package: ‘batchtools’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
#
# Attaching package: ‘assertthat’
#
#
# The following object is masked from ‘package:tibble’:
#
#     has_name

# %% [markdown]
# # Refactoring Crigen
#
# Current version of Crigen is based on hacking together a crispr simulator on top of dyngen. In this version of the code I will remove the majority first half of dyngen code and replace it with in silico network generation and kinetics. The second half of dyngen where simulating the network and converting the original bulk counts into 10x single cell counts.
#
# ## Create Networks using Module Extraction

# %%
fantom5 <- readRDS('../data/fantom5_nets.Rds')
grn_names <- names(fantom5)

# %%
load('../data/grna_libraries_meta.Rdata')

# %% [markdown]
# ## Simplifying Network Creating Code
#
# I am going to simplify this section code in the following manners. First i am reducing the number of parameters users can access. Second, I will only use genenetweavers modular subnetwork extraction method for network creation (I can add new methods later if I want to). Third, I am no longer tracking the number of Transcription Factors and E-Genes as I am sampling all out of the graph. However, I am going to keep housekeeping genes as they'll provide an excellent source of noise.

# %%
create_network <- function(num_tfs,
                           num_egenes,
                           num_hks,
                           bio_net=NULL,
                           bio_net_name=sample(grn_names, size=1),
                           verbose=FALSE) {
    
    if (is.null(bio_net)) {
        # if no biological network provided select one
        bio_net <- get_network(bio_net_name)
    }
    
    # sample grn and housekeeping network from a biological network
    message("Creating GRN...")
    grn <- create_grn(bio_net, num_tfs, num_egenes) %>% igraph::as_data_frame()
    message("GRN Created...")
    
    message("Creating HK Network...")
    hk_net <- create_hk_net(bio_net, num_hks) %>% igraph::as_data_frame()
    message("HK Network Created...")
    
    # merging sampled GRN and housekeeping network and extracting metadata
    feature_network <- bind_rows(grn, hk_net) %>%
                                mutate(valid_edge=ifelse(grepl('EGene', from) & grepl('EGene', to), TRUE,
                                                  ifelse(grepl('TF', from) | grepl('HK', from), TRUE, FALSE))) %>%
                                filter(valid_edge) %>% 
                                select(-weight)
    
    
    feature_info <- data.frame(feature_id=unique(c(feature_network$from, feature_network$to))) %>%
                        mutate(is_tf=ifelse(grepl('TF', feature_id), TRUE, FALSE),
                               is_hk=ifelse(grepl('HK', feature_id), TRUE, FALSE),
                               is_egene=ifelse(grepl('EGene', feature_id), TRUE, FALSE),
                               burn=TRUE)

    return (lst(feature_network, feature_info, verbose))
}

get_network <- function(bio_net_name, net_dir='../data/fantom5') {
    
    bio_net_fp <- file.path(net_dir, paste0(bio_net_name, '.Rds'))
    adj_mat <- readRDS(bio_net_fp)
    
    bio_net <- adj_mat %>%
                    Matrix::summary() %>% 
                    as.data.frame() %>% 
                    transmute(
                      i = rownames(adj_mat)[.data$i], 
                      j = colnames(adj_mat)[.data$j],
                      weight = .data$x) %>%
                    igraph::graph_from_data_frame(vertices = colnames(adj_mat))
    
    return (bio_net)
}

create_grn <- function(bio_net, num_tfs, num_egenes) {
    grn <- NA
    pass_qc <- FALSE
    
    # keep sampling TFs and E-Genes until we have created a network with
    # the desired number of Transcription Factors and E-Genes
    while (isFALSE(pass_qc)) {
        # sample biological network for TFs and E-Genes
        tfs <- sample_tfs(bio_net, num_tfs)
        egenes <- sample_egenes(bio_net, tfs, num_egenes)
        grn <- get_grn(tfs, egenes, bio_net)
        
        # rename genes so there anonymized
        genes_in_grn <- c(tfs, egenes)
        tf_mapper <- rename_genes(tfs, gene_type='TFs')
        egene_mapper <- rename_genes(egenes, gene_type='EGenes')
        
        gene_mapper <- append(tf_mapper, egene_mapper)
        V(grn)$name <- ifelse(V(grn)$name %in% genes_in_grn, gene_mapper[V(grn)$name], V(grn)$name)
        
        # check grn meets user parameters
        pass_qc <- grn_qc(grn, num_tfs, num_egenes)
    }
    
    return (grn)
}


create_hk_net <- function(bio_net, num_hks) {
    hk_net <- extract_housekeeping_net(bio_net, num_hks)
    hk_mapper <- rename_genes(V(hk_net)$name, gene_type='HK')
    
    # assigning new names to housekeeping genes
    V(hk_net)$name <- ifelse(V(hk_net)$name %in% names(hk_mapper), hk_mapper[V(hk_net)$name], V(hk_net)$name)
    return (hk_net)
}

get_grn <- function(tfs, egenes, bio_net) {
    
    grn <- bio_net %>% igraph::induced_subgraph(c(tfs, egenes))
    
    # remove any edges to my current tfs
    grn_df <- grn %>% igraph::as_data_frame() %>% select(from, to)
    
    # identify egenes that have no in degree edges
    missing_targets <- setdiff(egenes, grn_df$to)
    
    if (length(missing_targets) > 0) {
        # if there are egenes with missing edges reassign using degree distribution
        deg <- igraph::degree(grn)
        new_regs <- sample(names(deg), length(missing_targets), prob = deg, replace = TRUE)
        grn_df <- bind_rows(grn_df, tibble(from = new_regs, to = missing_targets))
    }
    
    grn <- grn_df %>% igraph::graph_from_data_frame(directed = TRUE)
    return (grn)
}

grn_qc <- function(grn, num_tfs, num_egenes){
    # check grn meets user parameters
    pass_qc <- FALSE
    genes_in_grn <- V(grn)$name
    
    tf_count <- length(genes_in_grn[grepl('TF', genes_in_grn)])
    egene_count <- length(genes_in_grn[grepl('EGene', genes_in_grn)])
    
    if (tf_count == num_tfs & egene_count == num_egenes){
        pass_qc <- TRUE
    }
    
    return (pass_qc)
}

rename_genes <- function(genes, gene_type="HK") {
    # rename all of the nodes sampled from bio_net to generic labels
    num_of_genes <- length(genes)
    
    if (gene_type == 'TFs') {
        gene_mapper <- set_names(paste0('TF', 1:num_of_genes), genes)
    } else if (gene_type == 'EGenes') {
        gene_mapper <- set_names(paste0('EGene', 1:num_of_genes), genes)
    } else {
        gene_mapper <- set_names(paste0('HK', 1:num_of_genes), genes)
    }
    
    return (gene_mapper)
}

################################ Separate RScript ################################ 
sample_egenes <- function(bio_net, tfs, num_egenes) {
    downstream_egenes <- get_nieghboring_nodes(bio_net, tfs, mode='out')
    page_rank <- run_page_rank(bio_net, c(tfs, downstream_egenes))
    egenes <- sample_page_rank_results(page_rank, tfs, num_egenes)
    
    return (egenes)
}

run_page_rank <- function(bio_net, gene_universe) {
    
    page_rank <- bio_net %>%
                    igraph::page_rank(directed = TRUE,
                                      weights = igraph::E(bio_net)$weight,
                                      damping=0.1)
    
    return (page_rank)
}

sample_page_rank_results <- function(page_rank, tfs, num_egenes) {
    
    sampled_egenes <- enframe(page_rank$vector, "feature_id", "score") %>% 
                          mutate(score = .data$score + runif(n(), 0, 1e-15)) %>% 
                          filter(!.data$feature_id %in% tfs) %>% 
                          sample_n(num_egenes, weight = .data$score) %>% 
                          pull(.data$feature_id) %>% unique()
    
    return (sampled_egenes)
}

extract_housekeeping_net <- function(bio_net, num_hks) {
    # extract housekeeping network using breadth first sampling
    seed_node <- sample(names(V(bio_net)), size=1)

    hk_names <- bio_net %>% 
                    igraph::bfs(seed_node, neimode = "all") %>% 
                    `[[`("order") %>% 
                    `[`(seq_len(num_hks)) %>% 
                    names()

    hk_net <- bio_net %>%
              igraph::induced_subgraph(hk_names) %>%
              igraph::as_data_frame() %>%
              filter(.data$from != .data$to) %>% # removing loops
              igraph::graph_from_data_frame(directed=TRUE)
    
    return (hk_net)
}

# %%
################################ Separate RScript ################################ 
sample_tfs <- function(bio_net, num_tfs) {
    # Extract Transcription Factor Interaction Network (TFI Net) from Biological Network. 
    # Then Run Modular Sampling across the TFI net to create an in silico TFI Net. 
    tf_net <- get_tf_net_from_bio_net(bio_net)
    
    # need to add test to check the num of tfs requested is lower than number of tfs in bio net provided
    assert_that(
        num_tfs <= gorder(tf_net),
        msg = paste0("Number of Transcription Factors in Biological Network (", nrow(realnet), ") is not large enough (>= ", nrow(model$feature_info), ")")
    )
    
    
    tfs_nodes <- modular_sample_net(tf_net, num_tfs)
    return (tfs_nodes)
}

get_tf_net_from_bio_net <- function(bio_net) {
    # identify nodes with greater than 1 out degree.
    nodes <- bio_net %>% 
                igraph::degree(mode='out') %>%
                as.data.frame %>%
                filter(. > 0) %>%
                rownames
    
    # extract the TF network and convert to undirected graph
    # this makes it easier to run modular sampling
    tf_net <- bio_net %>%
                igraph::induced_subgraph(nodes) %>%
                igraph::as.undirected()
    
    return (tf_net)
}

modular_sample_net <- function(net, num_nodes) {  
    # adding nodes to the extracted sub network until i read users specified size
    for (i in 1:num_nodes) {
        
        if (i == 1) {
            # first node is the seed node with is randomly sampled forom TF network
            sampled_nodes <- c(sample(V(net)$name, size=1))
        } else {
            node_to_add <- find_node_to_add(net, sampled_nodes)
            sampled_nodes <- c(sampled_nodes, node_to_add)
        }
    
    }
    
    return (sampled_nodes)
}

find_node_to_add <- function(net, sampled_nodes) {
    neighboring_nodes <- get_nieghboring_nodes(net, sampled_nodes)
    modularity_df <- calculate_modularity(net, sampled_nodes, neighboring_nodes)
    node_to_add <- get_node_with_max_modularity(modularity_df)
    
    return (node_to_add)
}

get_nieghboring_nodes <- function(net, sampled_nodes, mode='out') {
    print_num <- TRUE
    neighboring_nodes <- c()
    neighbors <- igraph::adjacent_vertices(net, sampled_nodes, mode='out')
    
    for (node in sampled_nodes) {
        node_neighbors <- neighbors[[node]]
        num_of_neighbors <- length(node_neighbors)
        
        for (i in 1:num_of_neighbors) {
            neighbor <- node_neighbors[i]$name
            neighboring_nodes <- c(neighboring_nodes, neighbor)
        }
    }
    
    return (neighboring_nodes)
}

calculate_modularity <- function(net, sampled_nodes, neighboring_nodes) {
    q <- c()
    nodes <- V(net)$name
    
    for (neigbor in neighboring_nodes) {
        proposed_nodes <- c(sampled_nodes, neigbor)
        membership_ids <- get_membership(proposed_nodes, nodes)

        proposed_q <- igraph::modularity(net, membership_ids)
        q <- c(q, proposed_q)
    }
    
    modularity_df <- data.frame(nodes=neighboring_nodes, modularity=as.double(q), stringsAsFactors=FALSE)
    return (modularity_df)
}

get_node_with_max_modularity <- function(modularity_df) {
    node_to_add <- modularity_df %>% filter(modularity == max(modularity)) %>% pull(nodes)
    
    # if there are multiple nodes with the same modularity randomly select one.
    if (length(node_to_add) > 1){
        node_to_add <- sample(node_to_add, size=1)
    }
    
    return (node_to_add)
}

get_membership <- function(proposed_nodes, tfs_net_nodes) {
    membership_id <- c()
    
    for (node in tfs_net_nodes){
        if (node %in% proposed_nodes){
            membership_id <- c(membership_id, 2)
        } else {
            membership_id <- c(membership_id, 1)
        }
    }
    
    return (membership_id)
}

# %% [markdown]
# ## Randomly Initializing Kinetics

# %%
initialize_kinetics <- function(model) {
    
    assert_that(!is.null(model$feature_info),
                !is.null(model$feature_network))
    
    # generate kinetics params and formulae
    message("Initializing Networks Kinetics...")
    model <- initializing_gene_kinetics(model)
    
    if (model$verbose) message("Creating Reacton Formulas...")
    reactions <- generate_reactions(model)
  
    # create variables
    fid <- model$feature_info$feature_id
    model$feature_info$mol_premrna <- paste0("mol_premrna_", fid)
    model$feature_info$mol_mrna <- paste0("mol_mrna_", fid)
    model$feature_info$mol_protein <- paste0("mol_protein_", fid)
  
    molecule_ids <- c(model$feature_info$mol_premrna, 
                      model$feature_info$mol_mrna,
                      model$feature_info$mol_protein)
    
    initial_state <- set_names(rep(0, length(molecule_ids)), molecule_ids)
    
    # return system
    model$simulation_system <- lst(reactions, molecule_ids, initial_state)
    
    return (model)
}

initializing_gene_kinetics <- function(model) {
  
    # fetch feature info and network
    rate_columns <- c("transcription_rate", "splicing_rate", "translation_rate", "mrna_halflife", "protein_halflife", "independence")
    interaction_columns <- c("effect", "strength", "hill")
    
    feature_info <- model$feature_info %>% add_columns(rate_columns, NA_real_)
    feature_network <- model$feature_network %>% add_columns(interaction_columns, NA_real_)
    
    # generate relatively stable kinetics for TFs
    feature_info <- feature_info %>% sample_rate_kinetics()
    feature_network <- feature_network %>% sample_interaction_kinetics()
    
    # calculate k
    dis_out <- calculate_dissociation(feature_info, feature_network)
    feature_info <- dis_out$feature_info
    feature_network <- dis_out$feature_network
    
    # calculate ba and a
    basal_df <- feature_network %>% 
                      rename(feature_id = .data$to) %>% 
                      group_by(feature_id) %>% 
                      summarise(basal = calculate_basal(.data$effect))
    
    feature_info <- feature_info %>%
                        left_join(basal_df, by = "feature_id") %>%
                        mutate(basal=ifelse(is.na(basal), 1, basal))
    
    feature_network <- qc_tf_interactions(feature_network, feature_info)

    model$feature_info <- feature_info
    model$feature_network <- feature_network

    return (model)
}

#' @importFrom GillespieSSA2 reaction
generate_reactions <- function(model) {
      
    # add helper information to feature info
    feature_info <- model$feature_info %>% 
                        left_join(model$feature_network %>% 
                                        group_by(feature_id = to) %>% 
                                        summarise(regulators = list(data.frame(from = .data$from,
                                                                               effect = .data$effect,
                                                                               strength = .data$strength)),
                                                  .groups = "drop"),
                                  by = "feature_id") %>% 
                        left_join(model$feature_network %>% 
                                    group_by(feature_id = from) %>% 
                                    summarise(num_targets = n()),
                                  by = "feature_id")

    # generate formula per feature
    out <- pbapply::pblapply(
        seq_len(nrow(feature_info)),
        function(i) {
            info <- feature_info %>% extract_row_to_list(i)
            fid <- info$feature_id

            w <- paste0("mol_premrna_", fid)
            x <- paste0("mol_mrna_", fid)
            y <- paste0("mol_protein_", fid)

            transcription_rate <- paste0("transcription_rate_", fid)
            splicing_rate <- paste0("splicing_rate_", fid)
            translation_rate <- paste0("translation_rate_", fid)
            mrna_decay_rate <- paste0("mrna_decay_rate_", fid)
            protein_decay_rate <- paste0("protein_decay_rate_", fid)

            basal <- paste0("bas_", fid)
            independence <- paste0("ind_", fid)

            if (!is.null(info$regulators)) {
                rid <- info$regulators$from
                eff <- info$regulators$effect
                str <- info$regulators$strength
                reg_ys <- paste0("mol_protein_", rid)
                reg_diss <- paste0("dis_", rid, "_", fid)
                reg_hills <- paste0("hill_", rid, "_", fid)
                reg_strs <- paste0("str_", rid, "_", fid)
                regulation_var <- paste0("chi_", rid, "_", fid)

                reg_affinity_calc <- paste(paste0(regulation_var, " = ", reg_strs, " * pow(", reg_ys, "/", reg_diss, ", ", reg_hills, "); "), collapse = "")
                
                numerator <-
                  if (sum(eff > 0) > 0) {
                    paste0(basal, " - pow(", independence, ",", sum(eff > 0), ") + ", paste("(", regulation_var[eff > 0], " + ", independence, ")", collapse = " * ", sep = ""))
                  } else {
                    basal
                  }
                denominator <- paste("(", regulation_var, " + 1)", collapse = " * ", sep = "")

                act_function <- paste0(reg_affinity_calc, transcription_rate, " * (", numerator, ")/(", denominator, ")")
             } else {
                act_function <- paste0(transcription_rate, " * ", basal)
                regulation_var <- character()
             }

             formulae <- list(
                # pre-mRNA production
                reaction(
                  name = paste0("transcription_", fid),
                  effect = set_names(1, w),
                  propensity = paste0(act_function)
                ),
                # splicing
                reaction(
                  name = paste0("splicing_", fid),
                  effect = set_names(c(1, -1), c(x, w)),
                  propensity = paste0(splicing_rate, " * ", w)
                ),
                # protein production
                reaction(
                  name = paste0("translation_", fid), 
                  effect = set_names(1, y),
                  propensity = paste0(translation_rate, " * ", x)
                ),
                # pre-mRNA degradation
                reaction(
                  name = paste0("premrna_degradation_", fid),
                  effect = set_names(-1, w),
                  propensity = paste0(mrna_decay_rate, " * ", w)
                ),
                # mRNA degradation
                reaction(
                  name = paste0("mrna_degradation_", fid),
                  effect = set_names(-1, x),
                  propensity = paste0(mrna_decay_rate, " * ", x)
                ),
                # protein degradation
                reaction(
                  name = paste0("protein_degradation_", fid),
                  effect = set_names(-1, y),
                  propensity = paste0(protein_decay_rate, " * ", y)
                )
              )

          formulae[[1]]$buffer_ids <- regulation_var
          return (formulae)
    })
  
    return(unlist(out, recursive = FALSE))
}

calculate_dissociation <- function(feature_info, feature_network) {
  remove <- c("max_premrna", "max_mrna", "max_protein", "dissociation", "k", "max_protein")
  
  feature_info <- feature_info[, !colnames(feature_info) %in% remove]
  feature_network <- feature_network[, !colnames(feature_network) %in% remove]
  
  feature_info <- feature_info %>%
                    mutate(max_premrna = transcription_rate / (mrna_decay_rate + splicing_rate),
                           max_mrna = splicing_rate / mrna_decay_rate * max_premrna,
                           max_protein = translation_rate / protein_decay_rate * max_mrna)
  
  feature_network <- feature_network %>% 
                        left_join(feature_info %>% select(from = feature_id, max_protein), by = "from") %>% 
                        mutate(dissociation = max_protein / 2)
  
  return(lst(feature_info, feature_network))
}

calculate_basal <- function(effects) {
    basal <- case_when(all(effects == -1) ~ 1,
                       all(effects == 1) ~ 0.0001,
                       TRUE ~ 0.5)
    
    return (basal)
}

sample_rate_kinetics <- function(feature_info) {
     feature_info <- feature_info %>%
                        mutate(independence = 1,
                               transcription_rate = runif(n(), 10, 20),
                               translation_rate = runif(n(), 100, 150),
                               mrna_halflife = runif(n(), 2.5, 5),
                               protein_halflife = runif(n(), 5, 10),
                               splicing_rate = log(2) / 2,
                               mrna_decay_rate = log(2) / .data$mrna_halflife,
                               protein_decay_rate = log(2) / .data$protein_halflife)
    
    return (feature_info)
}

sample_interaction_kinetics <- function(feature_network) {
    # this function needs to worked on so there is at least one condition where a TF is expressed
    feature_network <- feature_network %>%
                            mutate(effect = sample(c(-1L, 1L), n(), replace=TRUE, prob=c(.25, .75)),
                                   strength = 10 ^ runif(n(), log10(1), log10(100)),
                                   hill = rnorm_bounded(n(), 2, 2, min = 1, max = 10))
    
    return (feature_network)
}

qc_tf_interactions <- function(feature_network, feature_info) {
    tfs <- feature_info %>% filter(is_tf) %>% pull(feature_id)
    feature_network <- feature_network %>% mutate(row_i=row_number())
    
    for (tf in tfs) {
        tf_edges <- feature_network %>% filter(to == tf)
        all_edges <- tf_edges %>% nrow
        negative_edges <- tf_edges %>% filter(effect == -1L) %>% nrow
        
        if (all_edges == 0) {
            next()
        }
        
        if (negative_edges == all_edges) {
            edge_to_modify <- tf_edges %>% pull(row_i) %>% sample(1)
            feature_network[edge_to_modify, ]$effect <- 1
        }
    }
    
    return (feature_network)
}

simple_noise_simple <- function(feature_info, feature_network, mean, sd) {
    # satisfy r cmd check
    mrna_halflife <- protein_halflife <- NULL
    rate_cols <- c("transcription_rate", "splicing_rate", "translation_rate", "mrna_halflife", "protein_halflife")
    
    feature_info <- feature_info %>% 
                      mutate_at(c("basal"), ~ pmin(1, . * rnorm(length(.), mean = mean, sd = sd))) %>% 
                      mutate_at(rate_cols, ~ . * rnorm(length(.), mean = mean, sd = sd)) %>% 
                      mutate(mrna_decay_rate = log(2) / mrna_halflife, 
                             protein_decay_rate = log(2) / protein_halflife)
    
    feature_network <- feature_network %>%
                            mutate_at(c("strength", "hill"), ~ . * rnorm(length(.), mean = mean, sd = sd))
    
    return(lst(feature_info, feature_network))
}

add_columns <- function(df, colnames, fill = NA) {
    
    for (colname in colnames) {
        if (!colname %in% colnames(df)) {
            df[[colname]] <- fill
        }
    }
  
    return (df)
}

# %% [markdown]
# ## gRNA Characterization

# %%
# add ctrl grnas to the datasets
create_grnas <- function(model,
                         ntargets=NA,
                         on_target=NA,
                         off_target=NA,
                         ctrl_label='CTRL',
                         ngrna_per_target=3,
                         target_tf_only=TRUE,
                         crispr_type='Interference',
                         library=sample(names(grna_lib_meta), size=1)) {
    
    assert_that(crispr_type %in% c('Interference', 'Activation', 'Knockout'),
                msg=paste0("Crispr Type provided not: Interference, Activation, or Knockout"))
    
    model$crispr_params <- list(crispr_type=crispr_type, on_target=on_target,
                                off_target=off_target, ctrl_label=ctrl_label)
    
    # get the number of targets and select the targets  
    message("Selecting Target Genes...")
    ntargets <- get_ntargets(model, ntargets, target_tf_only)
    model$target_genes <- select_target_genes(model, ntargets, target_tf_only)
    
    # generate grna, multiplier_df, and model metadata
    message("Creating gRNA Characteristics...")
    model <- model %>%
                generate_grnas(ngrna_per_target, on_target, off_target, library) %>%
                generate_multiplier(crispr_type) %>%
                generate_simulation_meta()
    
    return (model)
}

get_ntargets <- function(model, ntargets, target_tf_only) {
    # number of potential targets
    feature_info <- model$feature_info
    
    if (isTRUE(target_tf_only)) {
       npotential_targets <- feature_info %>% filter(is_tf == TRUE & is_hk == FALSE) %>% nrow
    } else {
       npotential_targets <- feature_info %>% nrow
    }
    
    # get the number of target genes 
    if (is.na(ntargets)) {
        if (isTRUE(target_tf_only)) {
            ntargets <- feature_info %>% filter(is_tf == TRUE & is_hk == FALSE) %>% nrow
        } else {
            ntargets <- feature_info %>% nrow
        }
    }
    
    assert_that(
        ntargets <= npotential_targets,
        msg = paste0("Number of Target Genes Provided (", ntargets, ") is too large enough (>= number of avaliable genes ", npotential_targets, ")")
    )
    
    return (ntargets)
}

select_target_genes <- function(model, ntargets, target_tf_only) {
    # extract and randomly select target genes. This function heavily relays upon dyngen creating the 
    # gene regulatory network.
    feature_info <- model$feature_info
    
    if (target_tf_only == TRUE) {
        target_genes <- feature_info %>% filter(is_tf == TRUE) %>% pull(feature_id) %>% as.character
    } else {
        target_genes <- feature_info %>% pull(feature_id) %>% as.character
    }
    
    if (ntargets < length(target_genes)) {
        target_genes <- sample(target_genes, size=ntargets)
    }
    
    return (target_genes)
}

generate_grnas <- function(model, ngrna_per_target, on_target, off_target, library) {
    grna_seq <- 1:ngrna_per_target
    genes <- model$feature_info$feature_id
    model$grnas_meta <- data.frame(grna=model$crispr_params$ctrl_label, gene=NA, is_target=NA, on_target_activity=NA)
    grna_names <- lapply(model$target_genes, function (x) paste0(x, "-grna.", grna_seq)) %>% unlist()
    
    for (grna in grna_names) {
        target_gene <- str_split(grna, '-')[[1]][1]
        off_target_genes <- get_off_targets(genes, off_target, library)
        perturbed_genes <- c(target_gene, off_target_genes)
        genes_on_target <- get_on_targets(perturbed_genes, target_gene, on_target, library)
        
        meta <- data.frame(grna=rep(grna, length(perturbed_genes)),
                           gene=perturbed_genes,
                           is_target=ifelse(perturbed_genes == target_gene, TRUE, FALSE),
                           on_target_activity=genes_on_target)
        
        model$grnas_meta <- rbind(model$grnas_meta, meta)
    }
    
    return (model)
}

generate_multiplier <- function(model, crispr_type) { 
    multiplier <- NULL
    genes <- model$feature_info$feature_id
    base_multi <- set_names(rep(1, length(genes)), genes)
    grnas_names <- model$grnas_meta %>% pull(grna) %>% unique
      
    for (grna_name in grnas_names) {
        
        if (grna_name == model$crispr_params$ctrl_label) {
             grna_multi <- base_multi %>% t %>% as.data.frame
             rownames(grna_multi) <- c(model$crispr_params$ctrl_label)
        } else {
            grna_meta <- model$grnas_meta %>% filter(grna == grna_name)
            prtb_multi <- get_grna_multiplier(grna_meta, crispr_type)
            grna_multi <- update_grna_multiplier(prtb_multi, base_multi)
        }
        
        multiplier <- rbind(multiplier, grna_multi)
    }
    
    colnames(multiplier) <- paste0("transcription_rate_", colnames(multiplier))
    model$simulation_system$multiplier <- multiplier
    return (model)
}
                         
generate_simulation_meta <- function(model) {
    
    crispr_type <- model$crispr_params$crispr_type
    
    if (crispr_type != 'Knockout') {
        sample_percentages <- rep(1, nrow(model$simulation_system$multiplier))
    } else {
        sample_percentages <- calculate_sample_percentages(model)
    } 
    
    model$sim_meta <- data.frame(sim_name=rownames(model$simulation_system$multiplier),
                                 sample_percentage=sample_percentages) %>%
                            rowwise %>%
                            mutate(grna=str_split(sim_name, "_")[[1]][1],
                                   grna=ifelse('' == grna, sim_name, grna)) %>%
                            filter(sample_percentage != 0)
    
    return (model)
} 
                  
get_off_targets <- function(genes, off_target, library) {
    
    if (is.na(off_target)) {
        pdf <- grna_lib_meta[[library]]$off_pdf
        off_target <- sample(pdf$mismatch_up_to_2, size = 1, prob = pdf$prob)
    }
    
    off_target_genes <- sample(genes, size=off_target)
    return (off_target_genes)
}
                               
get_on_targets <- function(perturbed_genes, target_gene, on_target, library) {
    genes_on_target <- c()
    
    for (gene in perturbed_genes) {
        if (gene == target_gene & !is.na(on_target)) {
            sampled_activity <- on_target
        } else {
            # if user provided on target activity is na sample it
            pdf <- grna_lib_meta[[library]]$on_pdf
            sampled_activity <- sample(pdf$fusi_score, size = 1, prob = pdf$prob)
            sampled_activity  <-sampled_activity  / 100
        }
        
        genes_on_target <- c(genes_on_target, sampled_activity)
    }
    
    return (genes_on_target)
}

get_grna_multiplier <- function(grna, crispr_type) { 
    ngenes <- grna %>% nrow
    grna_name <- grna %>% pull(grna) %>% unique
    
    if (crispr_type == 'Knockout' & ngenes > 0) {
        grna_multipliers <- all_ko_combinations(grna$gene)
        model_names <- name_ko_models(grna_name, grna_multipliers)

    } else if (crispr_type == 'Knockout' & ngenes == 1) {
        grna_multipliers <- list(c(0, 1))
        grna_multipliers[[grna$gene]] <- c(0, 1)

        grna_multipliers <- grna_multipliers %>% as.data.frame
        model_names <- c(paste0(grna_name, '_', grna$gene, '-PRT'),
                         paste0(grna_name, '_', grna$gene, '-NT'))
    } else {
        grna_multipliers <- grna %>% select(on_target_activity) %>% t()
        colnames(grna_multipliers) <- grna %>% pull(gene)
        model_names <- grna_name
    }

    rownames(grna_multipliers) <- model_names
    return (grna_multipliers)
}
                         
update_grna_multiplier <- function (prtb_multi, base_multi) {
    multi <- NULL
    
    for (row in rownames(prtb_multi)) {
        sim_multi <- base_multi
        
        for (col in colnames(prtb_multi)) {
            sim_multi[[col]] <- prtb_multi[row, col]
        }
        
        sim_multi <- sim_multi %>% t %>% as.data.frame
        rownames(sim_multi) <- row
        
        multi <- rbind(multi, sim_multi)
    }
    
    return (multi)
}
                         
all_ko_combinations <- function(perturbed_genes) {
    # generating all of the potiential combinations of KO effects for a given gRNA
    combinations = list()

    for (gene in perturbed_genes) {
        combinations[[gene]] = 0:1
    }
    
    ko_combinations = combinations %>% as.data.frame %>% expand.grid()
    return (ko_combinations)
}

name_ko_models <- function(grna, ko_combos) {
    model_names <- c()

    for (i in 1:nrow(ko_combos)) {
        model_name <- grna

        for (col in colnames(ko_combos)) {
            value <- ko_combos[i, col]
            
            if (value == 0) {
                model_name <- paste0(model_name, "_", col, "-PRT")
            } else {
                model_name <- paste0(model_name, "_", col, "-NT")
            }
        }
        
        model_names <- c(model_names, model_name)
    }
    
    return (model_names)
}
                         
calculate_sample_percentages <- function(model){
    sample_percentages <- c()
    multiplier <- model$simulation_system$multiplier

    for (sim_name in rownames(multiplier)) {
        
        if (sim_name == model$crispr_params$ctrl_label) {
            sample_percentages <- c(sample_percentages, 1)
            next()
        }
        
        probs_mat <- NULL
        grna_name <- str_split(sim_name, "_")[[1]][1]
        grna_meta <- model$grnas_meta %>% filter(grna == grna_name)
        ko_combos <- multiplier[sim_name, grna_meta$gene]

        for (col_name in colnames(ko_combos)) { 
            gene_on_target <- grna_meta %>%
                                filter(gene == col_name) %>%
                                pull(on_target_activity)

            value <- ko_combos[sim_name, col_name]

            if (value == 1) {
                # probability of grna edit
                ko_combos[, col_name] <- gene_on_target
            } else {
                # probability of no edit
                ko_combos[, col_name] <- 1 - gene_on_target
            }
        }

        sim_perc <- matrixStats::rowProds(as.matrix(ko_combos))
        sample_percentages <- c(sample_percentages, sim_perc)
    }
    
    return (sample_percentages)
}

# %% [markdown]
# ## Simulation Code

# %%
run_simulation <- function(model,
                           noise_mean=1,
                           noise_sd=0.005,
                           nsims_per_grna=100,
                           burn_time=200,
                           perturb_time=400,
                           sampling_time=400,
                           keep_burn=FALSE,
                           keep_perturb=FALSE,
                           tau=30/3600,
                           census_interval=2,
                           compute_rna_velocity=FALSE,
                           ncpus=1,
                           mem='4G',
                           cluster='local',
                           time='24:00:00',
                           template="../templates/slurm.tmpl",
                           rscript=system("which Rscript", intern=TRUE)) {
    
    # setting up local or cluster parallelisms 
    model <- initialize_simulation_params(model, noise_mean, noise_sd,
                                           nsims_per_grna, burn_time,
                                           perturb_time, sampling_time,
                                           keep_burn, keep_perturb, tau,
                                           census_interval, compute_rna_velocity,
                                           cluster, ncpus, mem, time, template, rscript)
    
    sim_names <- model$simulation_system$sim_names
    
    if (cluster == 'local') {
        model <- precompile_reactions(model)
        cl <- model$simulation_system$resources$cl
        simulation <- pblapply(sim_names, simulate_cell, model=model, cl=cl)
    } else {
        njobs <- model$simulation_system$resources$njobs
        simulation <- run_jobs(sim_names, simulate_cell, njobs=njobs,
                               model=model, inject_noise=TRUE, compile_reactions=TRUE)
    }
    
    model <- merge_simulations(model, simulation)
    return (model)
}

initialize_simulation_params <- function(model, noise_mean, noise_sd, nsims_per_grna,
                                 burn_time, perturb_time, sampling_time, keep_burn,
                                 keep_perturb, tau, census_interval, compute_rna_velocity,
                                 cluster, ncpus, mem, time, template, rscript) {
    
     # todo list: need to add torque, lsf, sge
    assert_that(cluster %in% c('local', 'slurm'),
                msg=paste0("Parallelism Option Provided is not valid. Options are: local, Slurm"))
    
    sim_system <- model$simulation_system
    sim_names <- lapply(rownames(sim_system$multiplier),
                        function(x) paste0(x, '-sim.', 1:nsims_per_grna)) %>%
                        unlist()
    
    default_resources <- list(ncpus=ncpus, njobs=length(sim_names), memory=mem, walltime=time, rscript=rscript)
    
    setup_cluster(cluster, default_resources)
    
    sim_system$tau <- tau
    sim_system$cluster <- cluster
    sim_system$noise_sd <- noise_sd
    sim_system$sim_names <- sim_names
    sim_system$burn_time <- burn_time
    sim_system$keep_burn <- keep_burn
    sim_system$noise_mean <- noise_mean
    sim_system$keep_perturb <- keep_perturb
    sim_system$perturb_time <- perturb_time
    sim_system$resources <- default_resources
    sim_system$sampling_time <- sampling_time
    sim_system$nsims_per_grna <- nsims_per_grna
    sim_system$census_interval <- census_interval
    sim_system$compute_rna_velocity <- compute_rna_velocity
    
    model$simulation_system <- sim_system
    return (model)
}

simulate_cell <- function(sim, model, compile_reactions, inject_noise) {
    # get reusable parameters
    sim_system <- model$simulation_system
    cell_params <- create_sim_noise(sim, model) %>% extract_row_to_vector(sim)
    
    if (compile_reactions) {
        model <- precompile_reactions(model)
    }
    
    if (grepl('grna', sim)) {
        grna <- paste(str_split(sim, '-')[[1]][1:2], collapse='-')
        cell_multi <- sim_system$multiplier %>% extract_row_to_vector(grna)
        perturb_params <- calculate_perturb_parameters(cell_multi, cell_params)
    } else {
        perturb_params <- cell_params 
    }
    
    model <- model %>% 
                burn_phase(sim, cell_params) %>%
                perturb_phase(sim, perturb_params) %>%  
                sampling_phase(sim, perturb_params)
    
    model$simulation$kinetics <- cell_params
    return (model$simulation)
}

merge_simulations <- function(model, simulation) {
    sim <- list()
    sim_system <- model$simulation_system
    
    if (sim_system$keep_burn) {
        sim$burn <- extract_simulation_results(simulation, 'burn')
    }
    
    if (sim_system$keep_perturb) {
        sim$perturb <- extract_simulation_results(simulation, 'perturb')
    }
    
    sim$sampling <- extract_simulation_results(simulation, 'sampling')
    sim$sampling$meta <- sim$sampling$meta %>% as.data.frame %>% mutate(step_ix=row_number())
    
    kinetics_parameters <- extract_simulation_results(simulation, 'kinetics', FALSE)
    sim_system$kinetics_parameters <- kinetics_parameters %>% bind_rows()
    
    print(sim)
    
    model$simulation <- sim
    model$simulation_system <- sim_system
    return (model)
} 

extract_row_to_vector <- function(df, row_name) {
    row_vector <- df[row_name, ] %>%
                    t %>%
                    as.data.frame %>%
                    rename(param_value=colnames(.)[1]) %>% 
                    mutate(label=rownames(.)) %>% 
                    select(label, param_value) %>%
                    deframe()
    
    return (row_vector)
}
                        
precompile_reactions <- function(model) {
    # fetch paraneters and settings
    sim_system <- model$simulation_system
    reactions <- sim_system$reactions 
    state_ids <- names(sim_system$initial_state)
    buffer_ids <- unique(unlist(map(reactions, "buffer_ids")))
    parameters <- extract_parameters(model$feature_info, model$feature_network) %>% deframe()
    
    # compile prop funs
    comp_funs <- GillespieSSA2::compile_reactions(reactions = reactions,
                                                  buffer_ids = buffer_ids,
                                                  state_ids = state_ids,
                                                  params = parameters,
                                                  hardcode_params = FALSE,
                                                  fun_by = 1000L)
    
    model$simulation_system$compiled_reactions <- comp_funs
    return (model)
}
                        
calculate_perturb_parameters <- function(cell_multi, cell_params){
    kd_wprs <- names(cell_multi)
    perturb_params <- cell_params
    perturb_params[kd_wprs] <- perturb_params[kd_wprs] * cell_multi
    
    return (perturb_params)
}

burn_phase <- function(model, sim, params) {
    sim_system <- model$simulation_system
    
    # save results of burn phase and set sim_time to NULL
    model$simulation <- list()
    burn_time <- sim_system$burn_time
    initial_burn_state <- sim_system$initial_state
    
    burn_out <- run_gillispie(sim, 'burn', params, burn_time, initial_burn_state, sim_system)
    sim_system$initial_perturb_state <- burn_out$counts[nrow(burn_out$counts),]
    
    if (sim_system$keep_burn) {
        model$simulation$burn <- burn_out
    }
    
    model$simulation_system <- sim_system
    return (model)
}
                        
perturb_phase <- function(model, sim, params) {
    sim_system <- model$simulation_system
    
    # save results of burn phase and set sim_time to NULL
    perturb_time <- sim_system$perturb_time
    initial_perturb_state <- sim_system$initial_perturb_state
    
    perturb_out <- run_gillispie(sim, 'perturb', params, perturb_time, initial_perturb_state, sim_system)
    sim_system$initial_sampling_state <- perturb_out$counts[nrow(perturb_out$counts),]
    
    if (sim_system$keep_perturb) {
        model$simulation$perturb <- perturb_out
    }
    
    model$simulation_system <- sim_system
    return (model)
}
    
sampling_phase <- function(model, sim, params) {
    sim_system <- model$simulation_system
    
    # save results of burn phase and set sim_time to NULL
    sampling_time <- sim_system$sampling_time
    initial_sampling_state <- sim_system$initial_sampling_state
    
    sampling_out <- run_gillispie(sim, 'sampling', params, sampling_time, initial_sampling_state, sim_system)
    model$simulation$sampling <- sampling_out
    
    return (model)
}

run_gillispie <- function(sim, phase, params, sim_time, initial_state, sim_system) {
    
    ssa_algo <- ssa_etl(tau=sim_system$tau)
    reactions <- sim_system$compiled_reactions
    census_interval <- sim_system$census_interval
    
    # simulate cell
    out <- GillespieSSA2::ssa(sim_name = sim,
                              verbose = FALSE,
                              params = params,
                              method = ssa_algo,
                              reactions = reactions,
                              final_time = sim_time,
                              stop_on_neg_state = FALSE,
                              initial_state = initial_state,
                              census_interval = census_interval)
    
    out <- process_ssa_output(sim, phase, out, sim_time)
    colnames(out$counts) <- names(initial_state)
    
    return (out)
}
                        
process_ssa_output <- function(sim, phase, out, sim_time) {
    meta <- tibble(time = c(head(out$time, -1), sim_time)) %>%
                mutate(phase=phase, sim_name=sim, time=ceiling(time),
                       target_gene=str_split(sim_name, '-')[[1]][1]) %>%
                rowwise %>%
                mutate(grna=ifelse(target_gene == 'CTRL', str_split(sim_name, '-')[[1]][1],
                                   paste(str_split(sim_name, '-')[[1]][1:2], collapse='-')))
    
    counts <- out$state %>% Matrix::Matrix(sparse = TRUE)
    
    return(lst(meta, counts))
}
                        
extract_simulation_results <- function (sim, extractor, map_results=TRUE) {
    results <- list()
    
    for (sim_name in names(sim)) {
        results[[sim_name]] <- sim[[sim_name]][[extractor]]
    }
    
    if (isTRUE(map_results)) {
        results <- lst(meta=map_df(results, "meta"), counts=do.call(rbind, map(results, "counts")))
        results$meta <- results$meta %>% as.data.frame %>% mutate(step_ix=row_number())
    }
    
    return (results)
} 

##################################### Injecting Noise into Simulation #####################################

create_sim_noise <- function(sim, model) {
    # get noise parameters
    sd <- model$simulation_system$noise_sd
    mean <- model$simulation_system$noise_mean
    
    # inject noise into both individual gene rates and their interactions
    info <- model$feature_info %>% rate_noise(mean, sd)
    network <- model$feature_network %>% interaction_noise(mean, sd)
    
    out <- calculate_dissociation(info, network)
    params <- extract_parameters(out$feature_info, out$feature_network)
    
    values <- params %>% select(value) %>% t %>% as.data.frame
    colnames(values) <- params$id
    rownames(values) <- sim
    
    return (values)
}  
    
extract_parameters <- function(feature_info, feature_network) {
    # extract production / degradation rates, ind and bas
    feature_params <- feature_info %>% 
                        select(feature_id, transcription_rate, splicing_rate, translation_rate,
                               mrna_decay_rate, protein_decay_rate, bas = basal, ind = independence) %>% 
                        gather("param", "value", -feature_id) %>% 
                        mutate(id = paste0(param, "_", feature_id), type = "feature_info")

    # extract dis, hill, str
    edge_params <- feature_network %>% 
                        select(from, to, dis = dissociation, hill, str = strength) %>% 
                        gather("param", "value", -from, -to) %>% 
                        mutate(id = paste0(param, "_", from, "_", to), type = "feature_network")

    parameters <- bind_rows(feature_params, edge_params) %>% select(id, value)
    return (parameters)
}

    
rate_noise <- function(feature_info, mean, std) {
    mrna_halflife <- protein_halflife <- NULL
    rate_cols <- c("transcription_rate", "splicing_rate", "translation_rate", "mrna_halflife", "protein_halflife")
    
    feature_info <- feature_info %>% 
                          mutate_at(c("basal"), ~ pmin(1, . * rnorm(length(.), mean = mean, sd = std))) %>% 
                          mutate_at(rate_cols, ~ . * rnorm(length(.), mean = mean, sd = std)) %>% 
                          mutate(mrna_decay_rate = log(2) / mrna_halflife, 
                                 protein_decay_rate = log(2) / protein_halflife)
    
    return (feature_info)
}    

interaction_noise <- function(feature_network, mean, std) {
    # satisfy r cmd check
    feature_network <- feature_network %>%
                            mutate_at(c("strength", "hill"), ~ . * rnorm(length(.), mean = mean, sd = std))
    
    return(feature_network)
}
                        
############################ This code needs to be in a separate script file ############################

run_jobs <- function(inputs, FUN, njobs, ...) {
    # setting up all required parameters
    do_pb <- dopb()
    res <- listenv()
    
    if (do_pb) {
        pb <- startpb(0, njobs)
        on.exit(closepb(pb), add = TRUE)
    }
    
    # submit futures to cluster or cpu
    for (input in inputs) {
        res[[input]] %<-% { 
            FUN(input, ...)
        }
    }
    
    # monitor progression in computation and return list
    monitor_progress(res, njobs, do_pb, pb)
    return (as.list(res))
}

monitor_progress <- function(res, njobs, do_pb, pb) {
    resolved <- c()
    
    while (length(resolved) < njobs) {
        new_resolved <- c()

        for (i in seq_len(njobs)) {
            f <- futureOf(res[[i]])

            if (resolved(f) & !i %in% resolved) {
                resolved <- c(resolved, i)
                new_resolved <- c(new_resolved, i)
            }
        } 

        if (do_pb & length(new_resolved) > 0) {
            setpb(pb, length(resolved))
        }
    }
}

# %% [markdown]
# ## Create Experiment

# %%
# need to do some thinking about how to simulate multiplicity of infection
create_experiment <- function(model,
                              ncells=NA,
                              ncells_per_grna=100,
                              map_reference_ls=TRUE,
                              map_reference_cpm=TRUE,
                              realcount_fp='../data/GSE100866_CBMC_8K_13AB_10X-RNA_umi.rds',
                              realcount=readRDS(realcount_fp)) {
    
    check_experiment_parameters(model, ncells, ncells_per_grna)
    
    assert_that('dgCMatrix' %in% class(realcount),
                msg='Provided Realcount is not a matrix. Please provide a single cell expression matrix.')
    
    
    mrna_ids <- model$feature_info %>%
                    gather("mol", "val", mol_premrna, mol_mrna) %>% 
                    select(feature_id, mol, val) %>%
                    pull(val)
    
    cell_info <- sample_cells(model, ncells, ncells_per_grna)
    mrna_tsim_counts <- model$simulation$sampling$counts[cell_info$step_ix, mrna_ids, drop = FALSE]
    sim_counts <- simulate_counts(realcount, mrna_tsim_counts, map_reference_ls, map_reference_cpm)
    
    # separate out mRNA and pre-mRNA
    spliced_mrna <- sim_counts[, model$feature_info$mol_mrna, drop = FALSE]
    unspliced_mrna <- sim_counts[, model$feature_info$mol_premrna, drop = FALSE]
    
    # rename columns by genes and rownames by cell
    dimnames(spliced_mrna) <- list(cell_info$cell_id, model$feature_info$feature_id)
    dimnames(unspliced_mrna) <- list(cell_info$cell_id, model$feature_info$feature_id)
    
    # add together unspliced and spliced mrna
    mrna <- unspliced_mrna + spliced_mrna
    
    model$experiment <- lst(cell_info, mrna, unspliced_mrna, spliced_mrna)
    return (model)
}

check_experiment_parameters <- function(model, ncells, ncells_per_grna) {
    
    meta <- model$simulation$sampling$meta
    
    if (is.na(ncells) & is.na(ncells_per_grna)) {
        stop("Niether parameter ncells and ncells_per_grna have been defined. \n",
             "Chose one of the parameters and provide an integer.")
    } else if (is.integer(ncells) & is.integer(ncells_per_grna)) {
        stop("Both parameter ncells and ncells_per_grna have been defined. \n",
             "Chose one of the parameters and provide an integer.")
    } else if (is.numeric(ncells)) {
        num_cells <- ncells
    } else if (is.numeric(ncells_per_grna)){
        num_cells <- ncells_per_grna * length(unique(meta$grna))
    }
    
    if (num_cells > nrow(meta)) {
        stop(
          "Simulations only generated ", nrow(meta), " different datapoints, whereas ", num_cells, " cells were requested.\n",
          "Increase the number of simulations or decreasing the census interval (see `?run_simulation`)."
        )
    }
    
}

simulate_counts <- function(realcount, tsim_counts, map_reference_ls, map_reference_cpm) {
  
  lib_size <- calculate_library_size(realcount, tsim_counts, map_reference_ls)
  tsim_counts_cpm <- calculate_cpm(realcount, tsim_counts, map_reference_cpm)
  
  # simulate sampling of molecules
  tsim_counts_t <- sample_molecules(tsim_counts_cpm, lib_size)
  sim_counts <- Matrix::drop0(Matrix::t(tsim_counts_t))
  
  return (sim_counts)
}

calculate_library_size <- function(realcount, tsim_counts, map_reference_ls) {
  realcount_ls <- Matrix::rowSums(realcount)
  tsim_counts_ls <- Matrix::rowSums(tsim_counts)
  
  # simulate library size variation from real data
  if (map_reference_ls) {
    lib_size <- round(stats::quantile(realcount_ls, sort(stats::runif(length(tsim_counts_ls)))[order(order(tsim_counts_ls))])) %>% unname
  } else {
    lib_size <- tsim_counts_ls
  }
  
  return (lib_size)
}

calculate_cpm <- function(realcount, tsim_counts, map_reference_cpm) {
    realcount_cpm <- realcount
    tsim_counts_cpm <- tsim_counts
    realcount_ls <- Matrix::rowSums(realcount)
    tsim_counts_ls <- Matrix::rowSums(tsim_counts)
    realcount_cpm@x <- realcount@x / realcount_ls[realcount@i+1] * 1e6
    tsim_counts_cpm@x <- tsim_counts@x / tsim_counts_ls[tsim_counts@i+1] * 1e6

    # map real density on tsim counts
    tsim_counts_cpm_new <- tsim_counts_cpm

    if (map_reference_cpm) {
        tsim_counts_cpm_new@x <- stats::quantile(realcount_cpm@x, sort(stats::runif(length(tsim_counts_cpm@x)))[order(order(tsim_counts_cpm@x))]) %>% unname
    }
  
  return (tsim_counts_cpm_new)
}

sample_molecules <- function(tsim_counts_cpm, lib_size_new) {
  tsim_counts_t <- Matrix::t(tsim_counts_cpm)
  
  new_vals <- unlist(map(seq_along(lib_size_new), function(cell_i) {
    pi <- tsim_counts_t@p[[cell_i]]
    pj <- tsim_counts_t@p[[cell_i + 1]]
    
    if (pi != pj) {
      pix <- seq(pi + 1, pj, 1)
      gene_is <- tsim_counts_t@i[pix] + 1
      gene_vals <- tsim_counts_t@x[pix]
      lib_size <- lib_size_new[[cell_i]]
      
      # sample 'lib_size' molecules for each of the genes, weighted by 'gene_vals'
      rmultinom(1, lib_size, gene_vals)
      
    } else {
      integer(0)
    }
  })) %>% as.numeric
  
  tsim_counts_t@x <- new_vals
  return (tsim_counts_t)
}


###################################### Sampling Cell Code ######################################

sample_cells <- function(model, ncells, ncells_per_grna) {
    # need to add a test to make sure i have enough simulations to sample from
    sim_meta <- model$simulation$sampling$meta %>% as.data.frame
    
    if (!is.na(ncells)) {
        cell_info <- sampling_cells(sim_meta, ncells)
    }

    if (!is.na(ncells_per_grna)) {
        cell_info <- sampling_cells_per_grna(sim_meta, ncells_per_grna)
    }
    
    cell_info <-  cell_info %>%
                      mutate(cell_id = paste0("cell", row_number())) %>% 
                      select(cell_id, step_ix, target_gene, grna, sim_name, phase, time)

    return (cell_info)
}

sampling_cells <- function(sim_meta, num_cells) {
    sampled_cells <- NULL
    step_ixs <- sim_meta %>% pull(step_ix)
    
    for (row_i in 1:num_cells) {
            sampled_ix <- sample(step_ixs, size=1)
            row <- sim_meta %>% filter(step_ix == sampled_ix)
            
            if (row_i == 1) {
                sampled_cells <- row
            } else {
                sampled_cells <- rbind(row, sampled_cells)
            }
    }
    
    sampled_cells <- sampled_cells %>% as.data.frame
    return (sampled_cells)
}

sampling_cells_per_grna <- function(sim_meta, ncells_per_grna) {
    grna_sampled_cells <- list()
    grnas <- unique(sim_meta$grna)
    
    for (grna_name in grnas) {
        grna_meta <- sim_meta %>% filter(grna == grna_name)
        grna_sampled_cells[[grna_name]] <- sampling_cells(grna_meta, ncells_per_grna)
    }
    
    grna_sampled_cells <- bind_rows(grna_sampled_cells)
    return (grna_sampled_cells)
}

# %% [markdown]
# ## Testing Code

# %%
pbo <- pboptions(type = 'timer')
options(batchtools.progress=TRUE)

# %%
model <- create_network(num_tfs=10, num_egenes=100, num_hks=100)
# Out:
# Creating GRN...
#
# GRN Created...
#
# Creating HK Network...
#
# HK Network Created...

# %%
model$feature_network %>%
    filter(grepl('TF', from) & grepl('TF', to)) %>%
    igraph::graph_from_data_frame() %>% plot()
# Out:
# Plot with title “”

# %%
model <- model %>% initialize_kinetics()
# Out:
# Initializing Networks Kinetics...
#   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01s

# %% [markdown]
# ## Testing Simulation Code Works

# %%
temp <- model %>% 
            create_grnas(on_target=0, off_target=0, ngrna_per_target=1) %>%
            run_simulation(cluster='slurm', keep_burn=TRnsims_per_grna=1)
# Out:
# Selecting Target Genes...
#
# Creating gRNA Characteristics...
#   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01m 32s
# $sampling
# $sampling$meta
#      time    phase          sim_name target_gene        grna step_ix
# 1       0 sampling        CTRL-sim.1        CTRL        CTRL       1
# 2       3 sampling        CTRL-sim.1        CTRL        CTRL       2
# 3       5 sampling        CTRL-sim.1        CTRL        CTRL       3
# 4       7 sampling        CTRL-sim.1        CTRL        CTRL       4
# 5       9 sampling        CTRL-sim.1        CTRL        CTRL       5
# 6      11 sampling        CTRL-sim.1        CTRL        CTRL       6
# 7      13 sampling        CTRL-sim.1        CTRL        CTRL       7
# 8      15 sampling        CTRL-sim.1        CTRL        CTRL       8
# 9      17 sampling        CTRL-sim.1        CTRL        CTRL       9
# 10     19 sampling        CTRL-sim.1        CTRL        CTRL      10
# 11     21 sampling        CTRL-sim.1        CTRL        CTRL      11
# 12     23 sampling        CTRL-sim.1        CTRL        CTRL      12
# 13     25 sampling        CTRL-sim.1        CTRL        CTRL      13
# 14     27 sampling        CTRL-sim.1        CTRL        CTRL      14
# 15     29 sampling        CTRL-sim.1        CTRL        CTRL      15
# 16     31 sampling        CTRL-sim.1        CTRL        CTRL      16
# 17     33 sampling        CTRL-sim.1        CTRL        CTRL      17
# 18     35 sampling        CTRL-sim.1        CTRL        CTRL      18
# 19     37 sampling        CTRL-sim.1        CTRL        CTRL      19
# 20     39 sampling        CTRL-sim.1        CTRL        CTRL      20
# 21     41 sampling        CTRL-sim.1        CTRL        CTRL      21
# 22     43 sampling        CTRL-sim.1        CTRL        CTRL      22
# 23     45 sampling        CTRL-sim.1        CTRL        CTRL      23
# 24     47 sampling        CTRL-sim.1        CTRL        CTRL      24
# 25     49 sampling        CTRL-sim.1        CTRL        CTRL      25
# 26     51 sampling        CTRL-sim.1        CTRL        CTRL      26
# 27     53 sampling        CTRL-sim.1        CTRL        CTRL      27
# 28     55 sampling        CTRL-sim.1        CTRL        CTRL      28
# 29     57 sampling        CTRL-sim.1        CTRL        CTRL      29
# 30     59 sampling        CTRL-sim.1        CTRL        CTRL      30
# 31     61 sampling        CTRL-sim.1        CTRL        CTRL      31
# 32     63 sampling        CTRL-sim.1        CTRL        CTRL      32
# 33     65 sampling        CTRL-sim.1        CTRL        CTRL      33
# 34     67 sampling        CTRL-sim.1        CTRL        CTRL      34
# 35     69 sampling        CTRL-sim.1        CTRL        CTRL      35
# 36     71 sampling        CTRL-sim.1        CTRL        CTRL      36
# 37     73 sampling        CTRL-sim.1        CTRL        CTRL      37
# 38     75 sampling        CTRL-sim.1        CTRL        CTRL      38
# 39     77 sampling        CTRL-sim.1        CTRL        CTRL      39
# 40     79 sampling        CTRL-sim.1        CTRL        CTRL      40
# 41     81 sampling        CTRL-sim.1        CTRL        CTRL      41
# 42     83 sampling        CTRL-sim.1        CTRL        CTRL      42
# 43     85 sampling        CTRL-sim.1        CTRL        CTRL      43
# 44     87 sampling        CTRL-sim.1        CTRL        CTRL      44
# 45     89 sampling        CTRL-sim.1        CTRL        CTRL      45
# 46     91 sampling        CTRL-sim.1        CTRL        CTRL      46
# 47     93 sampling        CTRL-sim.1        CTRL        CTRL      47
# 48     95 sampling        CTRL-sim.1        CTRL        CTRL      48
# 49     97 sampling        CTRL-sim.1        CTRL        CTRL      49
# 50     99 sampling        CTRL-sim.1        CTRL        CTRL      50
# 51    101 sampling        CTRL-sim.1        CTRL        CTRL      51
# 52    103 sampling        CTRL-sim.1        CTRL        CTRL      52
# 53    105 sampling        CTRL-sim.1        CTRL        CTRL      53
# 54    107 sampling        CTRL-sim.1        CTRL        CTRL      54
# 55    109 sampling        CTRL-sim.1        CTRL        CTRL      55
# 56    111 sampling        CTRL-sim.1        CTRL        CTRL      56
# 57    113 sampling        CTRL-sim.1        CTRL        CTRL      57
# 58    115 sampling        CTRL-sim.1        CTRL        CTRL      58
# 59    117 sampling        CTRL-sim.1        CTRL        CTRL      59
# 60    119 sampling        CTRL-sim.1        CTRL        CTRL      60
# 61    121 sampling        CTRL-sim.1        CTRL        CTRL      61
# 62    123 sampling        CTRL-sim.1        CTRL        CTRL      62
# 63    125 sampling        CTRL-sim.1        CTRL        CTRL      63
# 64    127 sampling        CTRL-sim.1        CTRL        CTRL      64
# 65    129 sampling        CTRL-sim.1        CTRL        CTRL      65
# 66    131 sampling        CTRL-sim.1        CTRL        CTRL      66
# 67    133 sampling        CTRL-sim.1        CTRL        CTRL      67
# 68    135 sampling        CTRL-sim.1        CTRL        CTRL      68
# 69    137 sampling        CTRL-sim.1        CTRL        CTRL      69
# 70    139 sampling        CTRL-sim.1        CTRL        CTRL      70
# 71    141 sampling        CTRL-sim.1        CTRL        CTRL      71
# 72    143 sampling        CTRL-sim.1        CTRL        CTRL      72
# 73    145 sampling        CTRL-sim.1        CTRL        CTRL      73
# 74    147 sampling        CTRL-sim.1        CTRL        CTRL      74
# 75    149 sampling        CTRL-sim.1        CTRL        CTRL      75
# 76    151 sampling        CTRL-sim.1        CTRL        CTRL      76
# 77    153 sampling        CTRL-sim.1        CTRL        CTRL      77
# 78    155 sampling        CTRL-sim.1        CTRL        CTRL      78
# 79    157 sampling        CTRL-sim.1        CTRL        CTRL      79
# 80    159 sampling        CTRL-sim.1        CTRL        CTRL      80
# 81    161 sampling        CTRL-sim.1        CTRL        CTRL      81
# 82    163 sampling        CTRL-sim.1        CTRL        CTRL      82
# 83    165 sampling        CTRL-sim.1        CTRL        CTRL      83
# 84    167 sampling        CTRL-sim.1        CTRL        CTRL      84
# 85    169 sampling        CTRL-sim.1        CTRL        CTRL      85
# 86    171 sampling        CTRL-sim.1        CTRL        CTRL      86
# 87    173 sampling        CTRL-sim.1        CTRL        CTRL      87
# 88    175 sampling        CTRL-sim.1        CTRL        CTRL      88
# 89    177 sampling        CTRL-sim.1        CTRL        CTRL      89
# 90    179 sampling        CTRL-sim.1        CTRL        CTRL      90
# 91    181 sampling        CTRL-sim.1        CTRL        CTRL      91
# 92    183 sampling        CTRL-sim.1        CTRL        CTRL      92
# 93    185 sampling        CTRL-sim.1        CTRL        CTRL      93
# 94    187 sampling        CTRL-sim.1        CTRL        CTRL      94
# 95    189 sampling        CTRL-sim.1        CTRL        CTRL      95
# 96    191 sampling        CTRL-sim.1        CTRL        CTRL      96
# 97    193 sampling        CTRL-sim.1        CTRL        CTRL      97
# 98    195 sampling        CTRL-sim.1        CTRL        CTRL      98
# 99    197 sampling        CTRL-sim.1        CTRL        CTRL      99
# 100   199 sampling        CTRL-sim.1        CTRL        CTRL     100
# 101   201 sampling        CTRL-sim.1        CTRL        CTRL     101
# 102   203 sampling        CTRL-sim.1        CTRL        CTRL     102
# 103   205 sampling        CTRL-sim.1        CTRL        CTRL     103
# 104   207 sampling        CTRL-sim.1        CTRL        CTRL     104
# 105   209 sampling        CTRL-sim.1        CTRL        CTRL     105
# 106   211 sampling        CTRL-sim.1        CTRL        CTRL     106
# 107   213 sampling        CTRL-sim.1        CTRL        CTRL     107
# 108   215 sampling        CTRL-sim.1        CTRL        CTRL     108
# 109   217 sampling        CTRL-sim.1        CTRL        CTRL     109
# 110   219 sampling        CTRL-sim.1        CTRL        CTRL     110
# 111   221 sampling        CTRL-sim.1        CTRL        CTRL     111
# 112   223 sampling        CTRL-sim.1        CTRL        CTRL     112
# 113   225 sampling        CTRL-sim.1        CTRL        CTRL     113
# 114   227 sampling        CTRL-sim.1        CTRL        CTRL     114
# 115   229 sampling        CTRL-sim.1        CTRL        CTRL     115
# 116   231 sampling        CTRL-sim.1        CTRL        CTRL     116
# 117   233 sampling        CTRL-sim.1        CTRL        CTRL     117
# 118   235 sampling        CTRL-sim.1        CTRL        CTRL     118
# 119   237 sampling        CTRL-sim.1        CTRL        CTRL     119
# 120   239 sampling        CTRL-sim.1        CTRL        CTRL     120
# 121   241 sampling        CTRL-sim.1        CTRL        CTRL     121
# 122   243 sampling        CTRL-sim.1        CTRL        CTRL     122
# 123   245 sampling        CTRL-sim.1        CTRL        CTRL     123
# 124   247 sampling        CTRL-sim.1        CTRL        CTRL     124
# 125   249 sampling        CTRL-sim.1        CTRL        CTRL     125
# 126   251 sampling        CTRL-sim.1        CTRL        CTRL     126
# 127   253 sampling        CTRL-sim.1        CTRL        CTRL     127
# 128   255 sampling        CTRL-sim.1        CTRL        CTRL     128
# 129   257 sampling        CTRL-sim.1        CTRL        CTRL     129
# 130   259 sampling        CTRL-sim.1        CTRL        CTRL     130
# 131   261 sampling        CTRL-sim.1        CTRL        CTRL     131
# 132   263 sampling        CTRL-sim.1        CTRL        CTRL     132
# 133   265 sampling        CTRL-sim.1        CTRL        CTRL     133
# 134   267 sampling        CTRL-sim.1        CTRL        CTRL     134
# 135   269 sampling        CTRL-sim.1        CTRL        CTRL     135
# 136   271 sampling        CTRL-sim.1        CTRL        CTRL     136
# 137   273 sampling        CTRL-sim.1        CTRL        CTRL     137
# 138   275 sampling        CTRL-sim.1        CTRL        CTRL     138
# 139   277 sampling        CTRL-sim.1        CTRL        CTRL     139
# 140   279 sampling        CTRL-sim.1        CTRL        CTRL     140
# 141   281 sampling        CTRL-sim.1        CTRL        CTRL     141
# 142   283 sampling        CTRL-sim.1        CTRL        CTRL     142
# 143   285 sampling        CTRL-sim.1        CTRL        CTRL     143
# 144   287 sampling        CTRL-sim.1        CTRL        CTRL     144
# 145   289 sampling        CTRL-sim.1        CTRL        CTRL     145
# 146   291 sampling        CTRL-sim.1        CTRL        CTRL     146
# 147   293 sampling        CTRL-sim.1        CTRL        CTRL     147
# 148   295 sampling        CTRL-sim.1        CTRL        CTRL     148
# 149   297 sampling        CTRL-sim.1        CTRL        CTRL     149
# 150   299 sampling        CTRL-sim.1        CTRL        CTRL     150
# 151   301 sampling        CTRL-sim.1        CTRL        CTRL     151
# 152   303 sampling        CTRL-sim.1        CTRL        CTRL     152
# 153   305 sampling        CTRL-sim.1        CTRL        CTRL     153
# 154   307 sampling        CTRL-sim.1        CTRL        CTRL     154
# 155   309 sampling        CTRL-sim.1        CTRL        CTRL     155
# 156   311 sampling        CTRL-sim.1        CTRL        CTRL     156
# 157   313 sampling        CTRL-sim.1        CTRL        CTRL     157
# 158   315 sampling        CTRL-sim.1        CTRL        CTRL     158
# 159   317 sampling        CTRL-sim.1        CTRL        CTRL     159
# 160   319 sampling        CTRL-sim.1        CTRL        CTRL     160
# 161   321 sampling        CTRL-sim.1        CTRL        CTRL     161
# 162   323 sampling        CTRL-sim.1        CTRL        CTRL     162
# 163   325 sampling        CTRL-sim.1        CTRL        CTRL     163
# 164   327 sampling        CTRL-sim.1        CTRL        CTRL     164
# 165   329 sampling        CTRL-sim.1        CTRL        CTRL     165
# 166   331 sampling        CTRL-sim.1        CTRL        CTRL     166
# 167   333 sampling        CTRL-sim.1        CTRL        CTRL     167
# 168   335 sampling        CTRL-sim.1        CTRL        CTRL     168
# 169   337 sampling        CTRL-sim.1        CTRL        CTRL     169
# 170   339 sampling        CTRL-sim.1        CTRL        CTRL     170
# 171   341 sampling        CTRL-sim.1        CTRL        CTRL     171
# 172   343 sampling        CTRL-sim.1        CTRL        CTRL     172
# 173   345 sampling        CTRL-sim.1        CTRL        CTRL     173
# 174   347 sampling        CTRL-sim.1        CTRL        CTRL     174
# 175   349 sampling        CTRL-sim.1        CTRL        CTRL     175
# 176   351 sampling        CTRL-sim.1        CTRL        CTRL     176
# 177   353 sampling        CTRL-sim.1        CTRL        CTRL     177
# 178   355 sampling        CTRL-sim.1        CTRL        CTRL     178
# 179   357 sampling        CTRL-sim.1        CTRL        CTRL     179
# 180   359 sampling        CTRL-sim.1        CTRL        CTRL     180
# 181   361 sampling        CTRL-sim.1        CTRL        CTRL     181
# 182   363 sampling        CTRL-sim.1        CTRL        CTRL     182
# 183   365 sampling        CTRL-sim.1        CTRL        CTRL     183
# 184   367 sampling        CTRL-sim.1        CTRL        CTRL     184
# 185   369 sampling        CTRL-sim.1        CTRL        CTRL     185
# 186   371 sampling        CTRL-sim.1        CTRL        CTRL     186
# 187   373 sampling        CTRL-sim.1        CTRL        CTRL     187
# 188   375 sampling        CTRL-sim.1        CTRL        CTRL     188
# 189   377 sampling        CTRL-sim.1        CTRL        CTRL     189
# 190   379 sampling        CTRL-sim.1        CTRL        CTRL     190
# 191   381 sampling        CTRL-sim.1        CTRL        CTRL     191
# 192   383 sampling        CTRL-sim.1        CTRL        CTRL     192
# 193   385 sampling        CTRL-sim.1        CTRL        CTRL     193
# 194   387 sampling        CTRL-sim.1        CTRL        CTRL     194
# 195   389 sampling        CTRL-sim.1        CTRL        CTRL     195
# 196   391 sampling        CTRL-sim.1        CTRL        CTRL     196
# 197   393 sampling        CTRL-sim.1        CTRL        CTRL     197
# 198   395 sampling        CTRL-sim.1        CTRL        CTRL     198
# 199   397 sampling        CTRL-sim.1        CTRL        CTRL     199
# 200   399 sampling        CTRL-sim.1        CTRL        CTRL     200
# 201   400 sampling        CTRL-sim.1        CTRL        CTRL     201
# 202     0 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     202
# 203     3 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     203
# 204     5 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     204
# 205     7 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     205
# 206     9 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     206
# 207    11 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     207
# 208    13 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     208
# 209    15 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     209
# 210    17 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     210
# 211    19 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     211
# 212    21 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     212
# 213    23 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     213
# 214    25 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     214
# 215    27 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     215
# 216    29 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     216
# 217    31 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     217
# 218    33 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     218
# 219    35 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     219
# 220    37 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     220
# 221    39 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     221
# 222    41 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     222
# 223    43 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     223
# 224    45 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     224
# 225    47 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     225
# 226    49 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     226
# 227    51 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     227
# 228    53 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     228
# 229    55 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     229
# 230    57 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     230
# 231    59 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     231
# 232    61 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     232
# 233    63 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     233
# 234    65 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     234
# 235    67 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     235
# 236    69 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     236
# 237    71 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     237
# 238    73 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     238
# 239    75 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     239
# 240    77 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     240
# 241    79 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     241
# 242    81 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     242
# 243    83 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     243
# 244    85 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     244
# 245    87 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     245
# 246    89 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     246
# 247    91 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     247
# 248    93 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     248
# 249    95 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     249
# 250    97 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     250
# 251    99 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     251
# 252   101 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     252
# 253   103 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     253
# 254   105 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     254
# 255   107 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     255
# 256   109 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     256
# 257   111 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     257
# 258   113 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     258
# 259   115 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     259
# 260   117 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     260
# 261   119 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     261
# 262   121 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     262
# 263   123 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     263
# 264   125 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     264
# 265   127 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     265
# 266   129 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     266
# 267   131 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     267
# 268   133 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     268
# 269   135 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     269
# 270   137 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     270
# 271   139 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     271
# 272   141 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     272
# 273   143 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     273
# 274   145 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     274
# 275   147 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     275
# 276   149 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     276
# 277   151 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     277
# 278   153 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     278
# 279   155 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     279
# 280   157 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     280
# 281   159 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     281
# 282   161 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     282
# 283   163 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     283
# 284   165 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     284
# 285   167 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     285
# 286   169 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     286
# 287   171 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     287
# 288   173 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     288
# 289   175 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     289
# 290   177 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     290
# 291   179 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     291
# 292   181 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     292
# 293   183 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     293
# 294   185 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     294
# 295   187 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     295
# 296   189 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     296
# 297   191 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     297
# 298   193 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     298
# 299   195 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     299
# 300   197 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     300
# 301   199 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     301
# 302   201 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     302
# 303   203 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     303
# 304   205 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     304
# 305   207 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     305
# 306   209 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     306
# 307   211 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     307
# 308   213 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     308
# 309   215 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     309
# 310   217 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     310
# 311   219 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     311
# 312   221 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     312
# 313   223 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     313
# 314   225 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     314
# 315   227 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     315
# 316   229 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     316
# 317   231 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     317
# 318   233 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     318
# 319   235 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     319
# 320   237 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     320
# 321   239 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     321
# 322   241 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     322
# 323   243 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     323
# 324   245 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     324
# 325   247 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     325
# 326   249 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     326
# 327   251 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     327
# 328   253 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     328
# 329   255 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     329
# 330   257 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     330
# 331   259 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     331
# 332   261 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     332
# 333   263 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     333
# 334   265 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     334
# 335   267 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     335
# 336   269 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     336
# 337   271 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     337
# 338   273 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     338
# 339   275 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     339
# 340   277 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     340
# 341   279 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     341
# 342   281 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     342
# 343   283 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     343
# 344   285 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     344
# 345   287 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     345
# 346   289 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     346
# 347   291 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     347
# 348   293 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     348
# 349   295 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     349
# 350   297 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     350
# 351   299 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     351
# 352   301 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     352
# 353   303 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     353
# 354   305 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     354
# 355   307 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     355
# 356   309 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     356
# 357   311 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     357
# 358   313 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     358
# 359   315 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     359
# 360   317 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     360
# 361   319 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     361
# 362   321 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     362
# 363   323 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     363
# 364   325 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     364
# 365   327 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     365
# 366   329 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     366
# 367   331 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     367
# 368   333 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     368
# 369   335 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     369
# 370   337 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     370
# 371   339 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     371
# 372   341 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     372
# 373   343 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     373
# 374   345 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     374
# 375   347 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     375
# 376   349 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     376
# 377   351 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     377
# 378   353 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     378
# 379   355 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     379
# 380   357 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     380
# 381   359 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     381
# 382   361 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     382
# 383   363 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     383
# 384   365 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     384
# 385   367 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     385
# 386   369 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     386
# 387   371 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     387
# 388   373 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     388
# 389   375 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     389
# 390   377 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     390
# 391   379 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     391
# 392   381 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     392
# 393   383 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     393
# 394   385 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     394
# 395   387 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     395
# 396   389 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     396
# 397   391 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     397
# 398   393 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     398
# 399   395 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     399
# 400   397 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     400
# 401   399 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     401
# 402   400 sampling  TF7-grna.1-sim.1         TF7  TF7-grna.1     402
# 403     0 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     403
# 404     3 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     404
# 405     5 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     405
# 406     7 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     406
# 407     9 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     407
# 408    11 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     408
# 409    13 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     409
# 410    15 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     410
# 411    17 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     411
# 412    19 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     412
# 413    21 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     413
# 414    23 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     414
# 415    25 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     415
# 416    27 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     416
# 417    29 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     417
# 418    31 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     418
# 419    33 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     419
# 420    35 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     420
# 421    37 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     421
# 422    39 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     422
# 423    41 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     423
# 424    43 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     424
# 425    45 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     425
# 426    47 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     426
# 427    49 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     427
# 428    51 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     428
# 429    53 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     429
# 430    55 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     430
# 431    57 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     431
# 432    59 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     432
# 433    61 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     433
# 434    63 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     434
# 435    65 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     435
# 436    67 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     436
# 437    69 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     437
# 438    71 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     438
# 439    73 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     439
# 440    75 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     440
# 441    77 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     441
# 442    79 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     442
# 443    81 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     443
# 444    83 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     444
# 445    85 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     445
# 446    87 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     446
# 447    89 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     447
# 448    91 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     448
# 449    93 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     449
# 450    95 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     450
# 451    97 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     451
# 452    99 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     452
# 453   101 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     453
# 454   103 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     454
# 455   105 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     455
# 456   107 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     456
# 457   109 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     457
# 458   111 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     458
# 459   113 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     459
# 460   115 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     460
# 461   117 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     461
# 462   119 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     462
# 463   121 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     463
# 464   123 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     464
# 465   125 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     465
# 466   127 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     466
# 467   129 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     467
# 468   131 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     468
# 469   133 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     469
# 470   135 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     470
# 471   137 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     471
# 472   139 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     472
# 473   141 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     473
# 474   143 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     474
# 475   145 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     475
# 476   147 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     476
# 477   149 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     477
# 478   151 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     478
# 479   153 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     479
# 480   155 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     480
# 481   157 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     481
# 482   159 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     482
# 483   161 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     483
# 484   163 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     484
# 485   165 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     485
# 486   167 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     486
# 487   169 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     487
# 488   171 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     488
# 489   173 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     489
# 490   175 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     490
# 491   177 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     491
# 492   179 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     492
# 493   181 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     493
# 494   183 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     494
# 495   185 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     495
# 496   187 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     496
# 497   189 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     497
# 498   191 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     498
# 499   193 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     499
# 500   195 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     500
# 501   197 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     501
# 502   199 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     502
# 503   201 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     503
# 504   203 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     504
# 505   205 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     505
# 506   207 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     506
# 507   209 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     507
# 508   211 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     508
# 509   213 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     509
# 510   215 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     510
# 511   217 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     511
# 512   219 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     512
# 513   221 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     513
# 514   223 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     514
# 515   225 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     515
# 516   227 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     516
# 517   229 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     517
# 518   231 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     518
# 519   233 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     519
# 520   235 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     520
# 521   237 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     521
# 522   239 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     522
# 523   241 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     523
# 524   243 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     524
# 525   245 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     525
# 526   247 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     526
# 527   249 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     527
# 528   251 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     528
# 529   253 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     529
# 530   255 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     530
# 531   257 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     531
# 532   259 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     532
# 533   261 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     533
# 534   263 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     534
# 535   265 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     535
# 536   267 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     536
# 537   269 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     537
# 538   271 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     538
# 539   273 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     539
# 540   275 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     540
# 541   277 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     541
# 542   279 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     542
# 543   281 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     543
# 544   283 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     544
# 545   285 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     545
# 546   287 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     546
# 547   289 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     547
# 548   291 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     548
# 549   293 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     549
# 550   295 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     550
# 551   297 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     551
# 552   299 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     552
# 553   301 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     553
# 554   303 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     554
# 555   305 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     555
# 556   307 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     556
# 557   309 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     557
# 558   311 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     558
# 559   313 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     559
# 560   315 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     560
# 561   317 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     561
# 562   319 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     562
# 563   321 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     563
# 564   323 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     564
# 565   325 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     565
# 566   327 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     566
# 567   329 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     567
# 568   331 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     568
# 569   333 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     569
# 570   335 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     570
# 571   337 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     571
# 572   339 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     572
# 573   341 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     573
# 574   343 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     574
# 575   345 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     575
# 576   347 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     576
# 577   349 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     577
# 578   351 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     578
# 579   353 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     579
# 580   355 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     580
# 581   357 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     581
# 582   359 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     582
# 583   361 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     583
# 584   363 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     584
# 585   365 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     585
# 586   367 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     586
# 587   369 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     587
# 588   371 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     588
# 589   373 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     589
# 590   375 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     590
# 591   377 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     591
# 592   379 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     592
# 593   381 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     593
# 594   383 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     594
# 595   385 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     595
# 596   387 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     596
# 597   389 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     597
# 598   391 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     598
# 599   393 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     599
# 600   395 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     600
# 601   397 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     601
# 602   399 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     602
# 603   400 sampling  TF5-grna.1-sim.1         TF5  TF5-grna.1     603
# 604     0 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     604
# 605     3 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     605
# 606     5 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     606
# 607     7 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     607
# 608     9 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     608
# 609    11 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     609
# 610    13 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     610
# 611    15 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     611
# 612    17 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     612
# 613    19 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     613
# 614    21 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     614
# 615    23 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     615
# 616    25 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     616
# 617    27 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     617
# 618    29 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     618
# 619    31 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     619
# 620    33 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     620
# 621    35 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     621
# 622    37 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     622
# 623    39 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     623
# 624    41 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     624
# 625    43 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     625
# 626    45 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     626
# 627    47 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     627
# 628    49 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     628
# 629    51 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     629
# 630    53 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     630
# 631    55 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     631
# 632    57 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     632
# 633    59 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     633
# 634    61 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     634
# 635    63 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     635
# 636    65 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     636
# 637    67 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     637
# 638    69 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     638
# 639    71 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     639
# 640    73 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     640
# 641    75 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     641
# 642    77 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     642
# 643    79 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     643
# 644    81 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     644
# 645    83 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     645
# 646    85 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     646
# 647    87 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     647
# 648    89 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     648
# 649    91 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     649
# 650    93 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     650
# 651    95 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     651
# 652    97 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     652
# 653    99 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     653
# 654   101 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     654
# 655   103 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     655
# 656   105 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     656
# 657   107 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     657
# 658   109 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     658
# 659   111 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     659
# 660   113 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     660
# 661   115 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     661
# 662   117 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     662
# 663   119 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     663
# 664   121 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     664
# 665   123 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     665
# 666   125 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     666
# 667   127 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     667
# 668   129 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     668
# 669   131 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     669
# 670   133 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     670
# 671   135 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     671
# 672   137 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     672
# 673   139 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     673
# 674   141 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     674
# 675   143 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     675
# 676   145 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     676
# 677   147 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     677
# 678   149 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     678
# 679   151 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     679
# 680   153 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     680
# 681   155 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     681
# 682   157 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     682
# 683   159 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     683
# 684   161 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     684
# 685   163 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     685
# 686   165 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     686
# 687   167 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     687
# 688   169 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     688
# 689   171 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     689
# 690   173 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     690
# 691   175 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     691
# 692   177 sampling  TF6-grna.1-sim.1         TF6  TF6-grna.1     692
# ...
# [1783,]  .  1 27 34 18 32 . . ......
# [1784,]  .  . 28 29 18 47 . . ......
# [1785,]  .  . 20 37 24 43 . . ......
# [1786,]  .  . 29 31 15 31 . . ......
# [1787,]  .  1 27 41 11 30 . . ......
# [1788,]  .  1 27 32 12 29 1 . ......
# [1789,]  .  . 23 29 10 33 1 . ......
# [1790,]  .  . 21 42 12 32 1 . ......
# [1791,]  .  . 30 49 15 18 1 . ......
# [1792,]  .  . 25 38 14 21 1 . ......
# [1793,]  .  . 22 33 10 38 1 . ......
# [1794,]  .  . 24 43 17 37 1 . ......
# [1795,]  .  . 24 36 16 33 1 . ......
# [1796,]  .  1 32 28 16 35 1 . ......
# [1797,]  .  1 27 25 14 31 . . ......
# [1798,]  .  . 26 31 15 27 . . ......
# [1799,]  .  . 23 32 22 32 . . ......
# [1800,]  .  . 25 43 10 28 1 . ......
# [1801,]  .  . 24 42 15 25 . . ......
# [1802,]  .  . 27 38 18 27 2 . ......
# [1803,]  .  . 28 31 18 25 1 . ......
# [1804,]  .  . 27 33 19 35 1 . ......
# [1805,]  .  2 25 27 13 39 2 . ......
# [1806,]  .  1 23 24 17 42 . . ......
# [1807,]  .  1 25 24 20 34 2 . ......
# [1808,]  .  1 28 29 21 34 1 . ......
# [1809,]  .  . 21 36 14 33 . . ......
# [1810,]  1  . 18 27 13 34 2 . ......
# [1811,]  .  . 20 28  8 39 1 . ......
# [1812,]  .  . 20 27  9 38 . . ......
# [1813,]  .  . 18 42 16 41 1 . ......
# [1814,]  .  . 27 42 14 34 2 . ......
# [1815,]  .  . 33 31 15 25 1 . ......
# [1816,]  .  . 34 28 13 28 5 . ......
# [1817,]  .  . 30 32 16 27 4 . ......
# [1818,]  .  . 24 29 17 22 3 . ......
# [1819,]  .  . 26 40 10 31 1 . ......
# [1820,]  .  . 32 37 17 27 1 . ......
# [1821,]  .  . 29 36 19 22 1 . ......
# [1822,]  .  . 24 32 14 26 1 . ......
# [1823,]  .  . 17 35 13 39 . . ......
# [1824,]  .  . 27 34 24 42 1 . ......
# [1825,]  .  . 29 38 15 38 3 . ......
# [1826,]  .  . 26 36 16 30 1 . ......
# [1827,]  .  . 27 30 22 34 1 . ......
# [1828,]  .  . 28 39 18 36 2 . ......
# [1829,]  .  . 25 37 20 29 . . ......
# [1830,]  .  . 19 45 12 31 . . ......
# [1831,]  .  . 21 40 15 32 2 . ......
# [1832,]  .  . 19 33 16 27 . . ......
# [1833,]  .  . 24 37 16 26 2 . ......
# [1834,]  .  . 26 38 14 45 . . ......
# [1835,]  .  . 28 38 19 40 . . ......
# [1836,]  .  . 23 32 26 38 2 . ......
# [1837,]  .  . 24 32 19 30 1 . ......
# [1838,]  .  1 23 28  9 33 . . ......
# [1839,]  .  . 24 32 19 35 . . ......
# [1840,]  .  . 18 33 13 24 2 . ......
# [1841,]  .  1 18 34 12 30 2 . ......
# [1842,]  .  1 20 38 15 27 2 . ......
# [1843,]  .  2 18 31 15 27 3 . ......
# [1844,]  .  1 21 13  9 31 1 . ......
# [1845,]  .  2 19 31 11 33 1 . ......
# [1846,]  .  1 24 30 16 37 . . ......
# [1847,]  .  . 16 27 19 32 . . ......
# [1848,]  .  1 19 31 15 29 . . ......
# [1849,]  .  2 23 38 15 32 . . ......
# [1850,]  .  . 27 39 14 32 2 . ......
# [1851,]  .  1 30 34 13 38 2 . ......
# [1852,]  .  1 37 37 17 31 . . ......
# [1853,]  .  2 30 27 22 26 . . ......
# [1854,]  .  2 35 35 18 39 1 . ......
# [1855,]  .  4 33 39 13 35 1 . ......
# [1856,]  .  . 34 39 16 29 . . ......
# [1857,]  .  . 30 34 18 28 1 . ......
# [1858,]  .  . 24 32 21 33 1 . ......
# [1859,]  .  . 27 27 20 43 2 . ......
# [1860,]  .  1 28 35 13 44 . . ......
# [1861,]  .  . 24 33 12 38 . . ......
# [1862,]  .  1 26 27 12 38 2 . ......
# [1863,]  .  1 28 34 21 37 3 . ......
# [1864,]  .  2 21 31 12 24 3 . ......
# [1865,]  .  . 19 37 16 35 2 . ......
# [1866,]  .  1 17 25 18 36 1 . ......
# [1867,]  .  1 27 24 10 30 1 . ......
# [1868,]  .  1 28 37 12 33 1 . ......
# [1869,]  .  1 29 30 12 31 . . ......
# [1870,]  .  2 19 27 15 35 . . ......
# [1871,]  .  1 21 32 10 30 . . ......
# [1872,]  .  . 27 45 13 30 . . ......
# [1873,]  .  . 15 30 14 27 1 . ......
# [1874,]  .  . 19 26 16 23 4 . ......
# [1875,]  .  . 22 43 18 35 2 . ......
# [1876,]  .  . 31 53 16 26 2 . ......
# [1877,]  .  . 28 37 19 25 2 . ......
# [1878,]  .  . 30 37 23 30 1 . ......
# [1879,]  .  . 18 24 20 42 1 . ......
# [1880,]  .  . 17 32 16 44 1 . ......
# [1881,]  .  . 20 40 14 38 1 . ......
# [1882,]  .  . 18 47 21 40 1 . ......
# [1883,]  .  . 23 46 17 29 . . ......
# [1884,]  .  . 28 46 11 43 1 . ......
# [1885,]  .  . 27 36 16 46 . . ......
# [1886,]  .  . 23 39  9 35 . . ......
# [1887,]  .  . 17 37 17 28 1 . ......
# [1888,]  .  . 27 34 15 32 3 . ......
# [1889,]  .  . 28 36 21 37 4 . ......
# [1890,]  .  . 25 49 15 34 2 . ......
# [1891,]  .  . 26 34 18 35 1 . ......
# [1892,]  .  . 29 32 15 36 2 . ......
# [1893,]  .  . 23 31 21 34 3 . ......
# [1894,]  .  . 28 43 19 31 1 . ......
# [1895,]  .  . 27 37 16 40 . . ......
# [1896,]  .  . 24 37 15 36 . . ......
# [1897,]  .  1 26 45 10 35 1 . ......
# [1898,]  .  1 25 47 15 31 1 . ......
# [1899,]  .  1 21 48 20 39 2 . ......
# [1900,]  .  . 28 34 24 44 3 . ......
# [1901,]  .  . 22 42 18 39 1 . ......
# [1902,]  .  . 27 40 17 40 1 . ......
# [1903,]  .  . 23 34 17 34 3 . ......
# [1904,]  .  . 21 32 16 35 2 . ......
# [1905,]  .  . 18 34  8 37 1 . ......
# [1906,]  .  . 24 28 16 40 1 . ......
# [1907,]  .  . 27 31 20 23 1 . ......
# [1908,]  .  1 26 36 15 37 1 . ......
# [1909,]  .  . 34 31 17 38 . . ......
# [1910,]  .  . 35 32 14 34 1 . ......
# [1911,]  .  . 24 31 11 27 1 . ......
# [1912,]  .  . 30 35 21 30 1 . ......
# [1913,]  .  . 23 37 18 24 1 . ......
# [1914,]  .  . 15 33 18 28 . . ......
# [1915,]  .  . 22 38 19 40 . . ......
# [1916,]  .  . 25 35 21 31 2 . ......
# [1917,]  .  . 25 40 17 29 1 . ......
# [1918,]  .  . 21 40 16 39 3 . ......
# [1919,]  .  . 19 30 20 28 . . ......
# [1920,]  .  . 19 27 21 22 . . ......
# [1921,]  1  . 27 23 22 27 1 . ......
# [1922,]  .  . 29 30 22 29 1 . ......
# [1923,]  .  . 35 35 16 34 . . ......
# [1924,]  .  . 19 32 10 39 1 . ......
# [1925,]  .  . 24 33 10 43 . . ......
# [1926,]  .  . 18 26 12 30 1 . ......
# [1927,]  .  . 23 32 23 28 . . ......
# [1928,]  .  . 19 33 17 38 . . ......
# [1929,]  .  . 18 20 20 34 1 . ......
# [1930,]  .  . 16 33 25 35 . . ......
# [1931,]  .  . 28 32 19 42 . . ......
# [1932,]  .  . 28 37 25 30 . . ......
# [1933,]  .  . 30 29 17 25 1 . ......
# [1934,]  .  . 36 32 16 29 1 . ......
# [1935,]  .  . 24 32 22 22 . . ......
# [1936,]  .  . 32 29 19 23 . . ......
# [1937,]  .  . 30 27 19 26 . . ......
# [1938,]  .  1 28 32 16 19 1 . ......
# [1939,]  .  . 26 29 22 30 2 . ......
# [1940,]  .  . 32 36 21 29 3 . ......
# [1941,]  .  1 27 30 17 39 2 . ......
# [1942,]  .  1 30 25 12 35 1 . ......
# [1943,]  .  1 15 31 18 34 1 . ......
# [1944,]  .  . 24 31 21 36 . . ......
# [1945,]  .  . 28 27 12 35 1 . ......
# [1946,]  .  1 20 38 15 31 3 . ......
# [1947,]  .  . 23 38 13 31 1 . ......
# [1948,]  .  . 29 34 11 40 1 . ......
# [1949,]  .  . 32 22 12 32 3 . ......
# [1950,]  .  . 21 35 16 41 2 . ......
# [1951,]  .  . 24 35 15 35 . . ......
# [1952,]  .  . 23 29 11 26 2 . ......
# [1953,]  .  . 26 46 19 22 2 . ......
# [1954,]  .  . 31 36 14 24 1 . ......
# [1955,]  .  . 31 42  8 33 . . ......
# [1956,]  .  . 32 33 19 29 . . ......
# [1957,]  .  1 29 33 20 29 2 . ......
# [1958,]  .  1 26 41 13 36 3 . ......
# [1959,]  .  . 22 38 13 26 . . ......
# [1960,]  .  . 23 38 16 25 1 . ......
# [1961,]  .  . 28 26 21 32 3 . ......
# [1962,]  .  3 24 28 26 33 1 . ......
# [1963,]  .  3 24 25 28 51 . . ......
# [1964,]  .  1 17 30 21 32 2 . ......
# [1965,]  .  2 30 26 21 34 2 . ......
# [1966,]  .  2 24 26 13 24 1 . ......
# [1967,]  .  . 22 37 19 31 3 . ......
# [1968,]  .  4 15 34 24 32 1 . ......
# [1969,]  .  1 21 43 21 29 1 . ......
# [1970,]  .  2 21 30 21 37 . . ......
# [1971,]  .  1 22 37 19 30 2 . ......
# [1972,]  .  . 26 32 19 36 2 . ......
# [1973,]  .  1 17 27 21 23 1 . ......
# [1974,]  .  1 28 23  9 22 2 . ......
# [1975,]  .  1 22 31 12 20 . . ......
# [1976,]  .  1 25 36 18 27 . . ......
# [1977,]  .  . 24 38 23 26 . . ......
# [1978,]  .  1 21 40 16 32 2 . ......
# [1979,]  .  1 29 33 20 33 1 . ......
# [1980,]  .  1 24 32 19 38 1 . ......
# [1981,]  .  . 28 32 19 25 . . ......
# [1982,]  .  . 18 24 21 28 2 . ......
# [1983,]  .  1 23 31 18 36 . . ......
# [1984,]  .  . 23 42 17 27 . . ......
# [1985,]  .  . 22 37 19 25 1 . ......
# [1986,]  .  . 29 42 19 37 1 . ......
# [1987,]  .  . 13 37 16 37 1 . ......
# [1988,]  .  . 15 44 16 28 2 . ......
# [1989,]  .  . 20 39 12 21 . . ......
# [1990,]  .  . 21 38 14 24 . . ......
# [1991,]  .  1 22 30 18 29 . . ......
# [1992,]  .  . 22 41 19 28 . . ......
# [1993,]  .  . 20 39 18 38 1 . ......
# [1994,]  .  . 22 35 17 32 1 . ......
# [1995,]  .  . 28 29 14 33 2 . ......
# [1996,]  .  . 25 32 19 37 2 . ......
# [1997,]  .  . 25 38 23 35 2 . ......
# [1998,]  .  . 28 30 13 25 1 . ......
# [1999,]  .  . 31 42  7 28 2 . ......
# [2000,]  .  . 24 42 13 31 3 . ......
# [2001,]  .  . 24 41 13 31 1 . ......
# [2002,]  .  . 28 38 15 28 1 . ......
# [2003,]  .  . 21 41 14 33 . . ......
# [2004,]  .  . 28 39 18 26 1 . ......
# [2005,]  .  . 34 40 14 29 1 . ......
# [2006,]  .  1 21 40 13 32 2 . ......
# [2007,]  .  3 16 49 15 36 1 . ......
# [2008,]  .  . 20 38 17 27 . . ......
# [2009,]  .  . 14 44 13 44 . . ......
# [2010,]  .  1 19 35 14 32 . . ......
# [2011,]  .  . 22 38 22 38 2 . ......
# [2012,]  .  . 18 36 20 36 2 . ......
# [2013,]  .  . 19 36 19 30 3 . ......
# [2014,]  .  . 26 29 18 36 . . ......
# [2015,]  .  . 31 30 20 28 1 . ......
# [2016,]  .  . 37 38 25 30 1 . ......
# [2017,]  .  . 26 35 13 29 . . ......
# [2018,]  .  . 20 37 18 24 . . ......
# [2019,]  .  . 22 38 13 32 2 . ......
# [2020,]  .  2 31 39 12 38 2 . ......
# [2021,]  .  1 29 45 14 27 . . ......
# [2022,]  .  2 27 28 18 24 2 . ......
# [2023,]  .  3 28 28 15 29 3 . ......
# [2024,]  .  2 20 31 22 30 . . ......
# [2025,]  2  1 32 33 28 35 . . ......
# [2026,]  2  . 25 35 15 30 1 . ......
# [2027,]  2  . 23 34 14 34 . . ......
# [2028,]  3  . 24 32  8 38 . . ......
# [2029,]  2  . 22 37 17 35 1 . ......
# [2030,]  1  . 25 36 11 34 3 . ......
# [2031,]  2  . 25 30 25 34 1 . ......
# [2032,]  3  . 24 32 18 22 1 . ......
# [2033,]  4  1 20 34 18 26 1 . ......
# [2034,]  6  . 17 29 14 28 . . ......
# [2035,]  3  1 26 31 20 28 1 . ......
# [2036,]  3  . 26 38 11 33 1 . ......
# [2037,]  2  . 23 29  4 31 . . ......
# [2038,]  1  . 24 36 13 32 . . ......
# [2039,]  2  . 23 31 19 34 2 . ......
# [2040,]  1  . 20 43  9 42 2 . ......
# [2041,]  1  . 20 35 10 41 2 . ......
# [2042,]  .  . 29 35 21 35 2 . ......
# [2043,]  .  . 20 26 18 24 2 . ......
# [2044,]  .  . 19 32 15 23 1 . ......
# [2045,]  .  . 32 33 22 16 . . ......
# [2046,]  .  . 22 28 19 28 2 . ......
# [2047,]  .  . 23 31 18 28 . . ......
# [2048,]  .  . 19 27 20 31 2 . ......
# [2049,]  .  . 21 35 12 32 3 . ......
# [2050,]  3  . 25 38 14 34 6 . ......
# [2051,]  .  . 19 26 18 32 4 . ......
# [2052,]  1  1 24 31 10 34 1 . ......
# [2053,]  3  1 14 35 14 26 1 . ......
# [2054,]  4  1 23 23 24 30 2 . ......
# [2055,]  3  . 17 36 17 36 1 . ......
# [2056,]  1  1 20 28 19 32 . . ......
# [2057,]  2  1 18 31 19 36 . . ......
# [2058,]  .  . 23 39 19 40 1 . ......
# [2059,]  .  . 38 31 20 30 2 . ......
# [2060,]  .  1 33 30 21 31 3 . ......
# [2061,]  .  . 25 30 18 39 2 . ......
# [2062,]  .  . 24 31 14 31 2 . ......
# [2063,]  .  . 34 36 20 28 . . ......
# [2064,]  .  . 30 40 19 29 1 . ......
# [2065,]  .  . 25 43 17 29 2 . ......
# [2066,]  .  . 31 40 21 22 2 . ......
# [2067,]  .  . 24 34 19 30 3 . ......
# [2068,]  .  1 21 34 18 30 2 . ......
# [2069,]  .  1 20 34 25 31 2 . ......
# [2070,]  .  1 22 38 20 31 1 . ......
# [2071,]  .  2 26 39 19 36 2 . ......
# [2072,]  .  . 18 41 18 36 2 . ......
# [2073,]  .  . 21 43 15 38 1 . ......
# [2074,]  .  . 19 39 19 29 1 . ......
# [2075,]  .  . 21 31 18 42 1 . ......
# [2076,]  .  . 24 35 15 31 1 . ......
# [2077,]  .  1 24 27 16 25 1 . ......
# [2078,]  .  1 25 36 14 30 2 . ......
# [2079,]  .  1 24 36 15 29 . . ......
# [2080,]  .  . 33 26 12 33 1 . ......
# [2081,]  .  1 30 33 15 33 . . ......
# [2082,]  .  . 29 29 15 36 1 . ......
# [2083,]  .  . 37 26  8 35 1 . ......
# [2084,]  .  . 31 28 17 39 1 . ......
# [2085,]  .  . 22 39 12 32 1 . ......
# [2086,]  .  . 23 37 18 28 1 . ......
# [2087,]  1  . 24 35 18 35 2 . ......
# [2088,]  .  . 18 34 14 45 1 . ......
# [2089,]  .  . 14 37 12 29 1 . ......
# [2090,]  .  . 22 43 10 33 3 . ......
# [2091,]  .  1 24 39 12 30 . . ......
# [2092,]  .  . 21 37 12 29 1 . ......
# [2093,]  .  . 22 27 29 27 1 . ......
# [2094,]  .  . 23 28 14 31 3 . ......
# [2095,]  .  . 18 34 13 19 2 . ......
# [2096,]  .  . 30 29 19 30 2 . ......
# [2097,]  .  . 23 29 20 30 . . ......
# [2098,]  .  . 24 29 24 32 . . ......
# [2099,]  .  . 32 31 15 36 1 . ......
# [2100,]  .  . 34 24 16 40 1 . ......
# [2101,]  .  . 19 27 19 39 2 . ......
# [2102,]  .  . 21 28 20 38 4 . ......
# [2103,]  .  . 26 27 20 34 . . ......
# [2104,]  .  . 23 41 12 29 4 . ......
# [2105,]  .  . 16 44 10 41 2 . ......
# [2106,]  1  . 18 40 16 39 . . ......
# [2107,]  1  . 21 42 11 48 . . ......
# [2108,]  2  . 20 40 15 38 . . ......
# [2109,]  1  . 27 35 21 30 . . ......
# [2110,]  2  . 27 43 14 37 2 . ......
# [2111,]  2  . 31 41 11 45 1 . ......
# [2112,]  2  . 25 33 17 30 1 . ......
# [2113,]  .  . 29 33 13 31 1 . ......
# [2114,]  .  . 34 31 20 33 2 . ......
# [2115,]  .  . 28 28 19 27 3 . ......
# [2116,]  .  . 29 32 17 44 4 . ......
# [2117,]  .  . 30 35 14 37 4 . ......
# [2118,]  .  . 26 33 15 28 3 . ......
# [2119,]  .  . 21 35 17 29 1 . ......
# [2120,]  .  . 21 39 19 26 1 . ......
# [2121,]  .  . 18 44 21 34 1 . ......
# [2122,]  .  . 14 40 19 32 2 . ......
# [2123,]  1  . 20 42 19 25 2 . ......
# [2124,]  .  . 26 38 26 27 . . ......
# [2125,]  .  . 21 28 22 24 1 . ......
# [2126,]  .  . 30 30 18 20 1 . ......
# [2127,]  .  1 25 37 23 29 5 . ......
# [2128,]  .  . 28 30 20 31 2 . ......
# [2129,]  .  . 23 41 17 24 2 . ......
# [2130,]  .  . 42 39 18 33 1 . ......
# [2131,]  .  1 27 32 21 36 1 . ......
# [2132,]  .  . 22 36 17 27 2 . ......
# [2133,]  .  . 26 42 18 32 . . ......
# [2134,]  .  . 30 25 19 41 . . ......
# [2135,]  .  . 22 32 16 45 2 . ......
# [2136,]  .  . 30 22 21 39 1 . ......
# [2137,]  .  1 25 26 17 38 . . ......
# [2138,]  .  1 26 28 13 30 1 . ......
# [2139,]  .  . 26 28 13 30 . . ......
# [2140,]  .  1 29 24 11 27 1 . ......
# [2141,]  .  . 23 26 16 19 1 . ......
# [2142,]  .  . 17 34 15 28 1 . ......
# [2143,]  .  1 17 31 15 28 . . ......
# [2144,]  .  . 25 35 20 19 . . ......
# [2145,]  .  . 23 34 18 21 . . ......
# [2146,]  .  1 25 41 22 24 1 . ......
# [2147,]  .  2 24 34 18 26 2 . ......
# [2148,]  .  . 24 40 18 32 2 . ......
# [2149,]  .  . 27 31 18 26 . . ......
# [2150,]  1  . 20 41 14 33 1 . ......
# [2151,]  .  . 22 49 13 30 3 . ......
# [2152,]  .  . 18 47 11 37 3 . ......
# [2153,]  .  . 22 34  9 32 2 . ......
# [2154,]  .  . 29 30  9 26 2 . ......
# [2155,]  .  . 32 33 15 32 3 . ......
# [2156,]  4  . 30 42 14 28 3 . ......
# [2157,]  2  . 29 35 15 30 1 . ......
# [2158,]  .  . 20 31 16 29 1 . ......
# [2159,]  3  . 25 27 16 42 . . ......
# [2160,]  1  . 22 37 18 48 1 . ......
# [2161,]  .  . 29 32 13 37 . . ......
# [2162,]  .  . 34 32 11 24 1 . ......
# [2163,]  .  . 38 35 19 28 2 . ......
# [2164,]  1  . 40 36 23 27 1 . ......
# [2165,]  .  . 35 28 11 25 . . ......
# [2166,]  .  . 32 34 21 25 2 . ......
# [2167,]  .  . 28 50 18 38 . . ......
# [2168,]  .  . 27 38 16 35 1 . ......
# [2169,]  .  1 28 37 26 28 3 . ......
# [2170,]  .  . 20 33 14 32 2 . ......
# [2171,]  .  . 29 34 16 29 . . ......
# [2172,]  .  1 23 30 19 31 1 . ......
# [2173,]  .  . 20 32 15 26 . . ......
# [2174,]  .  . 30 33 15 34 . . ......
# [2175,]  .  . 21 26 18 30 . . ......
# [2176,]  .  1 24 25 20 42 . . ......
# [2177,]  .  1 27 39 13 34 1 . ......
# [2178,]  .  . 14 35 16 26 . . ......
# [2179,]  .  1 15 37 23 29 . . ......
# [2180,]  .  . 19 35 24 32 2 . ......
# [2181,]  .  . 16 44 26 28 2 . ......
# [2182,]  .  . 23 39 24 41 3 . ......
# [2183,]  .  . 25 39 23 42 1 . ......
# [2184,]  .  . 36 32 16 29 1 . ......
# [2185,]  .  . 26 48 19 27 1 . ......
# [2186,]  .  . 22 40 13 38 1 . ......
# [2187,]  .  . 24 43 12 31 1 . ......
# [2188,]  .  . 27 33 17 33 1 . ......
# [2189,]  .  . 15 28 15 37 3 . ......
# [2190,]  .  . 13 45 17 30 2 . ......
# [2191,]  .  . 27 37 20 29 3 . ......
# [2192,]  .  . 29 32 19 32 1 . ......
# [2193,]  .  . 30 37 28 30 . . ......
# [2194,]  .  . 28 32 22 29 . . ......
# [2195,]  .  . 31 26 21 30 1 . ......
# [2196,]  .  . 25 22 18 34 1 . ......
# [2197,]  .  . 29 26 13 29 . . ......
# [2198,]  .  . 31 36 14 25 . . ......
# [2199,]  .  . 28 36 15 36 3 . ......
# [2200,]  .  . 34 27 14 26 3 . ......
# [2201,]  .  . 34 32 12 45 2 . ......
# [2202,]  .  . 26 46 10 37 3 . ......
# [2203,]  .  2 24 39 17 31 3 . ......
# [2204,]  .  1 23 40 11 37 1 . ......
# [2205,]  .  1 35 24 11 40 1 . ......
# [2206,]  .  2 34 31 18 32 . . ......
# [2207,]  .  1 25 28 19 35 1 . ......
# [2208,]  .  1 27 38 19 44 2 . ......
# [2209,]  .  . 34 32 17 30 1 . ......
# [2210,]  .  . 25 36 24 33 1 . ......
# [2211,]  .  . 24 35 29 35 . . ......
#
#  .....suppressing 598 columns in show(); maybe adjust 'options(max.print= *, width = *)'
#  ..............................

# %%
# burn <- temp$simulation$burn
# perturb <- temp$simulation$perturb
sampling <- temp$simulation$sampling

mrna <- temp$feature_info %>% filter(is_tf) %>% pull(mol_mrna)
# premrna <- temp$feature_info %>%filter(is_tf) %>% pull(mol_premrna)
# proteins <- temp$feature_info %>% filter(is_tf) %>% pull(mol_protein)

molecules <- lst(mrna)

# %%
get_tf_expression <- function(meta, counts, molecule_ids) {
    new_meta <- NA
    meta$molecule_type <- NA
    meta$value <- NA

    for (row_i in 1:nrow(meta)) {
        for (type in names(molecule_ids)) {
            for (molecule in molecule_ids[[type]]) {
                row <- meta[row_i, ]

                row$molecule_type <- type
                row$molecule <- molecule
                row$value <- counts[row_i, molecule]

                new_meta <- rbind(new_meta, row)
            }
        }   
    }
    
    return (new_meta)
}

# %%
# burn_meta <- get_tf_expression(burn$meta, burn$counts, molecules)
# perturb_meta <- get_tf_expression(perturb$meta, perturb$counts, molecules)
sampling_meta <- get_tf_expression(sampling$meta, sampling$counts, molecules)

# %%
options(repr.plot.width=15, repr.plot.height=15)

# burn_tf_expr <- burn_meta %>%
#                     ggplot(aes(x=time, y=value, colour=molecule)) +
#                         geom_line() + facet_wrap(~target_gene)

# perturb_tf_expr <- perturb_meta %>%
#                     ggplot(aes(x=time, y=value, colour=molecule)) +
#                         geom_line() + facet_wrap(~target_gene)

sampling_tf_expr <- sampling_meta %>%
                    ggplot(aes(x=time, y=value, colour=molecule)) +
                        geom_line() + facet_wrap(~target_gene)

# %%
# burn_tf_expr

# %%
# perturb_tf_expr

# %%
sampling_tf_expr
# Out:
# Warning message:
# “Removed 1 row(s) containing missing values (geom_path).”
# plot without title

# %% [markdown]
# ## Testing Code to Generate Experiments

# %%
test <- temp %>% create_experiment()

# %%
names(test$experiment)
# Out:
# [1] "cell_info"      "mrna"           "unspliced_mrna" "spliced_mrna"
